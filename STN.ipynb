# %%
from collections import defaultdict
import argparse
import torch as th
import torch.nn as nn
import torch.nn.functional as F
import dgl
import dgl.function as fn
import dgl.nn as dglnn
import tqdm
from dgl.data.rdf import AIFBDataset, MUTAGDataset, BGSDataset, AMDataset
import pandas as pd
import numpy as np
import random as rd
import time

# %%
parser = argparse.ArgumentParser(description='RGCN')
parser.add_argument("--dropout", type=float, default=0,
        help="dropout probability")
parser.add_argument("--n-hidden", type=int, default=16,
        help="number of hidden units")
parser.add_argument("--gpu", type=int, default=-1,
        help="gpu")
parser.add_argument("--lr", type=float, default=1e-2,
        help="learning rate")
parser.add_argument("--n-bases", type=int, default=-1,
        help="number of filter weight matrices, default: -1 [use all]")
parser.add_argument("--n-layers", type=int, default=2,
        help="number of propagation rounds")
parser.add_argument("-e", "--n-epochs", type=int, default=50,
        help="number of training epochs")
parser.add_argument("--model_path", type=str, default=None,
        help='path for save the model')
parser.add_argument("--l2norm", type=float, default=0,
        help="l2 norm coef")
parser.add_argument("--use-self-loop", default=False, action='store_true',
        help="include self feature as a special relation")
fp = parser.add_mutually_exclusive_group(required=False)
fp.add_argument('--validation', dest='validation', action='store_true')
fp.add_argument('--testing', dest='validation', action='store_false')
parser.set_defaults(validation=True)

args = parser.parse_args(args=['-e','100','--n-layers','5','--testing','--gpu','0'])

# %% [markdown]
# ### CSVファイルからテンソルへの変換
# daskというライブラリを経由して、テンソルへと変換
# daskは大きなデータを扱う際にアシストしてくれるもの。学習の際に、サイズが大きいものをうまく扱う？
# ```
# import dask.dataframe as dd
# print("Loading CSV...")
# test = dd.read_csv("position-pass-position.csv", encoding = "UTF-8")
#
# print("Converting to Tensor...")
# test_tensor = th.tensor(test)
# ```

# %% [markdown]
# ### うまく行かなったのPandasで

# %% [markdown]
# ### グラフの構築
# 作ったテンソルをDGLに読み込ませるだけ

# %%
rel = pd.read_csv('data\STN\data.csv')
id = pd.read_csv('data\STN\list.csv')
pos_null = pd.read_csv('data\STN\pn.csv')
null_pos = pd.read_csv('data\STN\_np.csv')
t_link = pd.read_csv('data\STN\link.csv')
mini = pd.read_csv('data\STN\mini\list.csv')

# %%
graphdata = {
    ('position', 'pass','position'):(th.tensor(rel['fromid']),th.tensor(rel['toid'])),
    ('position','temporal','position'):(th.tensor(t_link['fromid']),th.tensor(t_link['toid'])),
    ('position','temporal','null'):(th.tensor(pos_null['fromid']),th.tensor(pos_null['nullid'])),
    ('null','temporal','position'):(th.tensor(null_pos['nullid']),th.tensor(null_pos['toid']))
}
g = dgl.heterograph(graphdata)

# %%
#label数２５
labels = th.tensor(id['posid'])
num_classes = 25 #len(g.ntypes)
"""
#label数４
labels = th.tensor(id['newpos'])
num_classes = 4 #len(g.ntypes)
"""
"""
#label数８
labels = th.tensor(id['8pos'])
num_classes = 8 #len(g.ntypes)
"""

# %%
category = 'position'
mask_wt = 0.7
final_num = len(mini)
num_node = g.num_nodes(category) - final_num

mask = [1] * int(num_node * mask_wt) + [0] * (num_node - int(num_node * mask_wt))
rd.shuffle(mask)
mask = mask + [0] * final_num

mask_wt = 0.2
mask_tr = [1] * int(final_num * mask_wt) + [0] * (final_num - int(final_num * mask_wt))
rd.shuffle(mask_tr)
mask_tr = [0] * (num_node - final_num) + mask_tr

train_mask = th.tensor(mask)
test_mask = th.tensor(mask_tr)
train_idx = th.nonzero(train_mask, as_tuple=False).squeeze()
test_idx = th.nonzero(test_mask, as_tuple=False).squeeze()
category_id = category
for i, ntype in enumerate(g.ntypes):
    if ntype == category:
        category_id = i

# %% [markdown]
# ### モデルの定義
# 今回はサンプルコードの中から`RelGraphConv`を引用する。使わないやつごと引用した

# %%
class RelGraphConvLayer(nn.Module):
    r"""Relational graph convolution layer.

    Parameters
    ----------
    in_feat : int
        Input feature size.
    out_feat : int
        Output feature size.
    rel_names : list[str]
        Relation names.
    num_bases : int, optional
        Number of bases. If is none, use number of relations. Default: None.
    weight : bool, optional
        True if a linear layer is applied after message passing. Default: True
    bias : bool, optional
        True if bias is added. Default: True
    activation : callable, optional
        Activation function. Default: None
    self_loop : bool, optional
        True to include self loop message. Default: False
    dropout : float, optional
        Dropout rate. Default: 0.0
    """
    def __init__(self,
                 in_feat,
                 out_feat,
                 rel_names,
                 num_bases,
                 *,
                 weight=True,
                 bias=True,
                 activation=None,
                 self_loop=False,
                 dropout=0.0):
        super(RelGraphConvLayer, self).__init__()
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.rel_names = rel_names
        self.num_bases = num_bases
        self.bias = bias
        self.activation = activation
        self.self_loop = self_loop

        self.conv = dglnn.HeteroGraphConv({
                rel : dglnn.GraphConv(in_feat, out_feat, norm='right', weight=False, bias=False)
                for rel in rel_names
            })

        self.use_weight = weight
        self.use_basis = num_bases < len(self.rel_names) and weight
        if self.use_weight:
            if self.use_basis:
                self.basis = dglnn.WeightBasis((in_feat, out_feat), num_bases, len(self.rel_names))
            else:
                self.weight = nn.Parameter(th.Tensor(len(self.rel_names), in_feat, out_feat))
                nn.init.xavier_uniform_(self.weight, gain=nn.init.calculate_gain('relu'))

        # bias
        if bias:
            self.h_bias = nn.Parameter(th.Tensor(out_feat))
            nn.init.zeros_(self.h_bias)

        # weight for self loop
        if self.self_loop:
            self.loop_weight = nn.Parameter(th.Tensor(in_feat, out_feat))
            nn.init.xavier_uniform_(self.loop_weight,
                                    gain=nn.init.calculate_gain('relu'))

        self.dropout = nn.Dropout(dropout)

    def forward(self, g, inputs):
        """Forward computation

        Parameters
        ----------
        g : DGLHeteroGraph
            Input graph.
        inputs : dict[str, torch.Tensor]
            Node feature for each node type.

        Returns
        -------
        dict[str, torch.Tensor]
            New node features for each node type.
        """
        g = g.local_var()
        if self.use_weight:
            weight = self.basis() if self.use_basis else self.weight
            wdict = {self.rel_names[i] : {'weight' : w.squeeze(0)}
                     for i, w in enumerate(th.split(weight, 1, dim=0))}
        else:
            wdict = {}

        if g.is_block:
            inputs_src = inputs
            inputs_dst = {k: v[:g.number_of_dst_nodes(k)] for k, v in inputs.items()}
        else:
            inputs_src = inputs_dst = inputs

        hs = self.conv(g, inputs, mod_kwargs=wdict)

        def _apply(ntype, h):
            if self.self_loop:
                h = h + th.matmul(inputs_dst[ntype], self.loop_weight)
            if self.bias:
                h = h + self.h_bias
            if self.activation:
                h = self.activation(h)
            return self.dropout(h)
        return {ntype : _apply(ntype, h) for ntype, h in hs.items()}

# %%
class RelGraphConvLayerHeteroAPI(nn.Module):
    r"""Relational graph convolution layer.

    Parameters
    ----------
    in_feat : int
        Input feature size.
    out_feat : int
        Output feature size.
    rel_names : list[str]
        Relation names.
    num_bases : int, optional
        Number of bases. If is none, use number of relations. Default: None.
    weight : bool, optional
        True if a linear layer is applied after message passing. Default: True
    bias : bool, optional
        True if bias is added. Default: True
    activation : callable, optional
        Activation function. Default: None
    self_loop : bool, optional
        True to include self loop message. Default: False
    dropout : float, optional
        Dropout rate. Default: 0.0
    """
    def __init__(self,
                 in_feat,
                 out_feat,
                 rel_names,
                 num_bases,
                 *,
                 weight=True,
                 bias=True,
                 activation=None,
                 self_loop=False,
                 dropout=0.0):
        super(RelGraphConvLayerHeteroAPI, self).__init__()
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.rel_names = rel_names
        self.num_bases = num_bases
        self.bias = bias
        self.activation = activation
        self.self_loop = self_loop

        self.use_weight = weight
        self.use_basis = num_bases < len(self.rel_names) and weight
        if self.use_weight:
            if self.use_basis:
                self.basis = dglnn.WeightBasis((in_feat, out_feat), num_bases, len(self.rel_names))
            else:
                self.weight = nn.Parameter(th.Tensor(len(self.rel_names), in_feat, out_feat))
                nn.init.xavier_uniform_(self.weight, gain=nn.init.calculate_gain('relu'))

        # bias
        if bias:
            self.h_bias = nn.Parameter(th.Tensor(out_feat))
            nn.init.zeros_(self.h_bias)

        # weight for self loop
        if self.self_loop:
            self.loop_weight = nn.Parameter(th.Tensor(in_feat, out_feat))
            nn.init.xavier_uniform_(self.loop_weight,
                                    gain=nn.init.calculate_gain('relu'))

        self.dropout = nn.Dropout(dropout)

    def forward(self, g, inputs):
        """Forward computation

        Parameters
        ----------
        g : DGLHeteroGraph
            Input graph.
        inputs : dict[str, torch.Tensor]
            Node feature for each node type.

        Returns
        -------
        dict[str, torch.Tensor]
            New node features for each node type.
        """
        g = g.local_var()
        if self.use_weight:
            weight = self.basis() if self.use_basis else self.weight
            wdict = {self.rel_names[i] : {'weight' : w.squeeze(0)}
                     for i, w in enumerate(th.split(weight, 1, dim=0))}
        else:
            wdict = {}

        inputs_src = inputs_dst = inputs

        for srctype,_,_ in g.canonical_etypes:
            g.nodes[srctype].data['h'] = inputs[srctype]

        if self.use_weight:
            g.apply_edges(fn.copy_u('h', 'm'))
            m = g.edata['m']
            for rel in g.canonical_etypes:
                _, etype, _ = rel
                g.edges[rel].data['h*w_r'] =  th.matmul(m[rel], wdict[etype]['weight'])
        else:
            g.apply_edges(fn.copy_u('h', 'h*w_r'))

        g.update_all(fn.copy_e('h*w_r', 'm'), fn.sum('m', 'h'))

        def _apply(ntype):
            h = g.nodes[ntype].data['h']
            if self.self_loop:
                h = h + th.matmul(inputs_dst[ntype], self.loop_weight)
            if self.bias:
                h = h + self.h_bias
            if self.activation:
                h = self.activation(h)
            return self.dropout(h)
        return {ntype : _apply(ntype) for ntype in g.dsttypes}

# %%
class RelGraphEmbed(nn.Module):
    r"""Embedding layer for featureless heterograph."""
    def __init__(self,
                 g,
                 embed_size,
                 embed_name='embed',
                 activation=None,
                 dropout=0.0):
        super(RelGraphEmbed, self).__init__()
        self.g = g
        self.embed_size = embed_size
        self.embed_name = embed_name
        self.activation = activation
        self.dropout = nn.Dropout(dropout)

        # create weight embeddings for each node for each relation
        self.embeds = nn.ParameterDict()
        for ntype in g.ntypes:
            embed = nn.Parameter(th.Tensor(g.number_of_nodes(ntype), self.embed_size))
            nn.init.xavier_uniform_(embed, gain=nn.init.calculate_gain('relu'))
            self.embeds[ntype] = embed

    def forward(self, block=None):
        """Forward computation

        Parameters
        ----------
        block : DGLHeteroGraph, optional
            If not specified, directly return the full graph with embeddings stored in
            :attr:`embed_name`. Otherwise, extract and store the embeddings to the block
            graph and return.

        Returns
        -------
        DGLHeteroGraph
            The block graph fed with embeddings.
        """
        return self.embeds

# %%
class EntityClassify(nn.Module):
    def __init__(self,
                 g,
                 h_dim, out_dim,
                 num_bases,
                 num_hidden_layers=1,
                 dropout=0,
                 use_self_loop=False):
        super(EntityClassify, self).__init__()
        self.g = g
        self.h_dim = h_dim
        self.out_dim = out_dim
        self.rel_names = list(set(g.etypes))
        self.rel_names.sort()
        if num_bases < 0 or num_bases > len(self.rel_names):
            self.num_bases = len(self.rel_names)
        else:
            self.num_bases = num_bases
        self.num_hidden_layers = num_hidden_layers
        self.dropout = dropout
        self.use_self_loop = use_self_loop

        self.embed_layer = RelGraphEmbed(g, self.h_dim)
        self.layers = nn.ModuleList()
        # i2h
        self.layers.append(RelGraphConvLayer(
            self.h_dim, self.h_dim, self.rel_names,
            self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
            dropout=self.dropout, weight=False))
        # h2h
        for i in range(self.num_hidden_layers):
            self.layers.append(RelGraphConvLayer(
                self.h_dim, self.h_dim, self.rel_names,
                self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
                dropout=self.dropout))
        # h2o
        self.layers.append(RelGraphConvLayer(
            self.h_dim, self.out_dim, self.rel_names,
            self.num_bases, activation=None,
            self_loop=self.use_self_loop))

    def forward(self, h=None, blocks=None):
        if h is None:
            # full graph training
            h = self.embed_layer()
        if blocks is None:
            # full graph training
            for layer in self.layers:
                h = layer(self.g, h)
        else:
            # minibatch training
            for layer, block in zip(self.layers, blocks):
                h = layer(block, h)
        return h

    def inference(self, g, batch_size, device, num_workers, x=None):
        """Minibatch inference of final representation over all node types.

        ***NOTE***
        For node classification, the model is trained to predict on only one node type's
        label.  Therefore, only that type's final representation is meaningful.
        """

        if x is None:
            x = self.embed_layer()

        for l, layer in enumerate(self.layers):
            y = {
                k: th.zeros(
                    g.number_of_nodes(k),
                    self.h_dim if l != len(self.layers) - 1 else self.out_dim)
                for k in g.ntypes}

            sampler = dgl.dataloading.MultiLayerFullNeighborSampler(1)
            dataloader = dgl.dataloading.NodeDataLoader(
                g,
                {k: th.arange(g.number_of_nodes(k)) for k in g.ntypes},
                sampler,
                batch_size=batch_size,
                shuffle=True,
                drop_last=False,
                num_workers=num_workers)

            for input_nodes, output_nodes, blocks in tqdm.tqdm(dataloader):
                block = blocks[0].to(device)

                h = {k: x[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
                h = layer(block, h)

                for k in h.keys():
                    y[k][output_nodes[k]] = h[k].cpu()

            x = y
        return y

# %%
class EntityClassify_HeteroAPI(nn.Module):
    def __init__(self,
                 g,
                 h_dim, out_dim,
                 num_bases,
                 num_hidden_layers=1,
                 dropout=0,
                 use_self_loop=False):
        super(EntityClassify_HeteroAPI, self).__init__()
        self.g = g
        self.h_dim = h_dim
        self.out_dim = out_dim
        self.rel_names = list(set(g.etypes))
        self.rel_names.sort()
        if num_bases < 0 or num_bases > len(self.rel_names):
            self.num_bases = len(self.rel_names)
        else:
            self.num_bases = num_bases
        self.num_hidden_layers = num_hidden_layers
        self.dropout = dropout
        self.use_self_loop = use_self_loop

        self.embed_layer = RelGraphEmbed(g, self.h_dim)
        self.layers = nn.ModuleList()
        # i2h
        self.layers.append(RelGraphConvLayerHeteroAPI(
            self.h_dim, self.h_dim, self.rel_names,
            self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
            dropout=self.dropout, weight=False))
        # h2h
        for i in range(self.num_hidden_layers):
            self.layers.append(RelGraphConvLayerHeteroAPI(
                self.h_dim, self.h_dim, self.rel_names,
                self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
                dropout=self.dropout))
        # h2o
        self.layers.append(RelGraphConvLayerHeteroAPI(
            self.h_dim, self.out_dim, self.rel_names,
            self.num_bases, activation=None,
            self_loop=self.use_self_loop))

    def forward(self, h=None, blocks=None):
        if h is None:
            # full graph training
            h = self.embed_layer()
        if blocks is None:
            # full graph training
            for layer in self.layers:
                h = layer(self.g, h)
        else:
            # minibatch training
            for layer, block in zip(self.layers, blocks):
                h = layer(block, h)
        return h

    def inference(self, g, batch_size, device, num_workers, x=None):
        """Minibatch inference of final representation over all node types.

        ***NOTE***
        For node classification, the model is trained to predict on only one node type's
        label.  Therefore, only that type's final representation is meaningful.
        """

        if x is None:
            x = self.embed_layer()

        for l, layer in enumerate(self.layers):
            y = {
                k: th.zeros(
                    g.number_of_nodes(k),
                    self.h_dim if l != len(self.layers) - 1 else self.out_dim)
                for k in g.ntypes}

            sampler = dgl.dataloading.MultiLayerFullNeighborSampler(1)
            dataloader = dgl.dataloading.NodeDataLoader(
                g,
                {k: th.arange(g.number_of_nodes(k)) for k in g.ntypes},
                sampler,
                batch_size=batch_size,
                shuffle=True,
                drop_last=False,
                num_workers=num_workers)

            for input_nodes, output_nodes, blocks in tqdm.tqdm(dataloader):
                block = blocks[0].to(device)

                h = {k: x[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
                h = layer(block, h)

                for k in h.keys():
                    y[k][output_nodes[k]] = h[k].cpu()

            x = y
        return y

# %% [markdown]
# ### ノード分類の実装
# ここから作ったグラフを使って学習を行う。

# %%
# split dataset into train, validate, test
if args.validation:
    val_idx = train_idx[:len(train_idx) // 5]
    train_idx = train_idx[len(train_idx) // 5:]
else:
    val_idx = train_idx

# %%
# check cuda
use_cuda = args.gpu >= 0 and th.cuda.is_available()
if use_cuda:
    th.cuda.set_device(args.gpu)
    g = g.to('cuda:%d' % args.gpu)
    labels = labels.cuda()
    train_idx = train_idx.cuda()
    test_idx = test_idx.cuda()

# %%
# create model
model = EntityClassify(g,
                       args.n_hidden,
                       num_classes,
                       num_bases=args.n_bases,
                       num_hidden_layers=args.n_layers - 2,
                       dropout=args.dropout,
                       use_self_loop=args.use_self_loop)

# %%
if use_cuda:
        model.cuda()

# %%
# optimizer
optimizer = th.optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.l2norm)

# %%
# training loop
print("start training...")
dur = []
model.train()
for epoch in range(args.n_epochs):
    optimizer.zero_grad()
    if epoch > 5:
        t0 = time.time()
    logits = model()[category]
    loss = F.cross_entropy(logits[train_idx], labels[train_idx])
    loss.backward()
    optimizer.step()
    t1 = time.time()

    if epoch > 5:
        dur.append(t1 - t0)
    train_acc = th.sum(logits[train_idx].argmax(dim=1) == labels[train_idx]).item() / len(train_idx)
    val_loss = F.cross_entropy(logits[val_idx], labels[val_idx])
    val_acc = th.sum(logits[val_idx].argmax(dim=1) == labels[val_idx]).item() / len(val_idx)
    print("Epoch {:05d} | Train Acc: {:.4f} | Train Loss: {:.4f} | Valid Acc: {:.4f} | Valid loss: {:.4f} | Time: {:.4f}".
         format(epoch, train_acc, loss.item(), val_acc, val_loss.item(), np.average(dur)))
print()
if args.model_path is not None:
    th.save(model.state_dict(), args.model_path)

model.eval()
logits = model.forward()[category]
test_loss = F.cross_entropy(logits[test_idx], labels[test_idx])
test_acc = th.sum(logits[test_idx].argmax(dim=1) == labels[test_idx]).item() / len(test_idx)
print("Test Acc: {:.4f} | Test loss: {:.4f}".format(test_acc, test_loss.item()))
print()
# Out:
# start training...
# Epoch 00000 | Train Acc: 0.3267 | Train Loss: 1.3862 | Valid Acc: 0.3267 | Valid loss: 1.3862 | Time: nan
# Epoch 00001 | Train Acc: 0.4135 | Train Loss: 1.3711 | Valid Acc: 0.4135 | Valid loss: 1.3711 | Time: nan
# Epoch 00002 | Train Acc: 0.4135 | Train Loss: 1.3517 | Valid Acc: 0.4135 | Valid loss: 1.3517 | Time: nan
# Epoch 00003 | Train Acc: 0.4135 | Train Loss: 1.3266 | Valid Acc: 0.4135 | Valid loss: 1.3266 | Time: nan
# Epoch 00004 | Train Acc: 0.4135 | Train Loss: 1.2953 | Valid Acc: 0.4135 | Valid loss: 1.2953 | Time: nan
# Epoch 00005 | Train Acc: 0.4135 | Train Loss: 1.2589 | Valid Acc: 0.4135 | Valid loss: 1.2589 | Time: nan
# Epoch 00006 | Train Acc: 0.4135 | Train Loss: 1.2250 | Valid Acc: 0.4135 | Valid loss: 1.2250 | Time: 0.0300
# Epoch 00007 | Train Acc: 0.4134 | Train Loss: 1.2113 | Valid Acc: 0.4134 | Valid loss: 1.2113 | Time: 0.0295
# Epoch 00008 | Train Acc: 0.4148 | Train Loss: 1.2038 | Valid Acc: 0.4148 | Valid loss: 1.2038 | Time: 0.0293
# Epoch 00009 | Train Acc: 0.4239 | Train Loss: 1.1854 | Valid Acc: 0.4239 | Valid loss: 1.1854 | Time: 0.0300
# Epoch 00010 | Train Acc: 0.4043 | Train Loss: 1.1672 | Valid Acc: 0.4043 | Valid loss: 1.1672 | Time: 0.0302
# Epoch 00011 | Train Acc: 0.4378 | Train Loss: 1.1561 | Valid Acc: 0.4378 | Valid loss: 1.1561 | Time: 0.0300
# Epoch 00012 | Train Acc: 0.4251 | Train Loss: 1.1501 | Valid Acc: 0.4251 | Valid loss: 1.1501 | Time: 0.0299
# Epoch 00013 | Train Acc: 0.4156 | Train Loss: 1.1443 | Valid Acc: 0.4156 | Valid loss: 1.1443 | Time: 0.0299
# Epoch 00014 | Train Acc: 0.4149 | Train Loss: 1.1360 | Valid Acc: 0.4149 | Valid loss: 1.1360 | Time: 0.0298
# Epoch 00015 | Train Acc: 0.4224 | Train Loss: 1.1243 | Valid Acc: 0.4224 | Valid loss: 1.1243 | Time: 0.0298
# Epoch 00016 | Train Acc: 0.4660 | Train Loss: 1.1094 | Valid Acc: 0.4660 | Valid loss: 1.1094 | Time: 0.0298
# Epoch 00017 | Train Acc: 0.5536 | Train Loss: 1.0926 | Valid Acc: 0.5536 | Valid loss: 1.0926 | Time: 0.0298
# Epoch 00018 | Train Acc: 0.5313 | Train Loss: 1.0763 | Valid Acc: 0.5313 | Valid loss: 1.0763 | Time: 0.0299
# Epoch 00019 | Train Acc: 0.4967 | Train Loss: 1.0629 | Valid Acc: 0.4967 | Valid loss: 1.0629 | Time: 0.0301
# Epoch 00020 | Train Acc: 0.4927 | Train Loss: 1.0499 | Valid Acc: 0.4927 | Valid loss: 1.0499 | Time: 0.0301
# Epoch 00021 | Train Acc: 0.5168 | Train Loss: 1.0305 | Valid Acc: 0.5168 | Valid loss: 1.0305 | Time: 0.0301
# Epoch 00022 | Train Acc: 0.5620 | Train Loss: 1.0037 | Valid Acc: 0.5620 | Valid loss: 1.0037 | Time: 0.0300
# Epoch 00023 | Train Acc: 0.6052 | Train Loss: 0.9751 | Valid Acc: 0.6052 | Valid loss: 0.9751 | Time: 0.0300
# Epoch 00024 | Train Acc: 0.6177 | Train Loss: 0.9481 | Valid Acc: 0.6177 | Valid loss: 0.9481 | Time: 0.0301
# Epoch 00025 | Train Acc: 0.6179 | Train Loss: 0.9205 | Valid Acc: 0.6179 | Valid loss: 0.9205 | Time: 0.0301
# Epoch 00026 | Train Acc: 0.6255 | Train Loss: 0.8890 | Valid Acc: 0.6255 | Valid loss: 0.8890 | Time: 0.0301
# Epoch 00027 | Train Acc: 0.6373 | Train Loss: 0.8539 | Valid Acc: 0.6373 | Valid loss: 0.8539 | Time: 0.0301
# Epoch 00028 | Train Acc: 0.6457 | Train Loss: 0.8188 | Valid Acc: 0.6457 | Valid loss: 0.8188 | Time: 0.0302
# Epoch 00029 | Train Acc: 0.6525 | Train Loss: 0.7863 | Valid Acc: 0.6525 | Valid loss: 0.7863 | Time: 0.0302
# Epoch 00030 | Train Acc: 0.6588 | Train Loss: 0.7553 | Valid Acc: 0.6588 | Valid loss: 0.7553 | Time: 0.0302
# Epoch 00031 | Train Acc: 0.6833 | Train Loss: 0.7226 | Valid Acc: 0.6833 | Valid loss: 0.7226 | Time: 0.0302
# Epoch 00032 | Train Acc: 0.6993 | Train Loss: 0.6888 | Valid Acc: 0.6993 | Valid loss: 0.6888 | Time: 0.0302
# Epoch 00033 | Train Acc: 0.7198 | Train Loss: 0.6567 | Valid Acc: 0.7198 | Valid loss: 0.6567 | Time: 0.0301
# Epoch 00034 | Train Acc: 0.7372 | Train Loss: 0.6267 | Valid Acc: 0.7372 | Valid loss: 0.6267 | Time: 0.0302
# Epoch 00035 | Train Acc: 0.7536 | Train Loss: 0.5962 | Valid Acc: 0.7536 | Valid loss: 0.5962 | Time: 0.0302
# Epoch 00036 | Train Acc: 0.7684 | Train Loss: 0.5643 | Valid Acc: 0.7684 | Valid loss: 0.5643 | Time: 0.0302
# Epoch 00037 | Train Acc: 0.7799 | Train Loss: 0.5354 | Valid Acc: 0.7799 | Valid loss: 0.5354 | Time: 0.0302
# Epoch 00038 | Train Acc: 0.7906 | Train Loss: 0.5079 | Valid Acc: 0.7906 | Valid loss: 0.5079 | Time: 0.0301
# Epoch 00039 | Train Acc: 0.8015 | Train Loss: 0.4798 | Valid Acc: 0.8015 | Valid loss: 0.4798 | Time: 0.0300
# Epoch 00040 | Train Acc: 0.8134 | Train Loss: 0.4541 | Valid Acc: 0.8134 | Valid loss: 0.4541 | Time: 0.0300
# Epoch 00041 | Train Acc: 0.8213 | Train Loss: 0.4298 | Valid Acc: 0.8213 | Valid loss: 0.4298 | Time: 0.0300
# Epoch 00042 | Train Acc: 0.8289 | Train Loss: 0.4070 | Valid Acc: 0.8289 | Valid loss: 0.4070 | Time: 0.0300
# Epoch 00043 | Train Acc: 0.8350 | Train Loss: 0.3862 | Valid Acc: 0.8350 | Valid loss: 0.3862 | Time: 0.0299
# Epoch 00044 | Train Acc: 0.8396 | Train Loss: 0.3676 | Valid Acc: 0.8396 | Valid loss: 0.3676 | Time: 0.0299
# Epoch 00045 | Train Acc: 0.8467 | Train Loss: 0.3506 | Valid Acc: 0.8467 | Valid loss: 0.3506 | Time: 0.0299
# Epoch 00046 | Train Acc: 0.8572 | Train Loss: 0.3314 | Valid Acc: 0.8572 | Valid loss: 0.3314 | Time: 0.0298
# Epoch 00047 | Train Acc: 0.8723 | Train Loss: 0.3118 | Valid Acc: 0.8723 | Valid loss: 0.3118 | Time: 0.0298
# Epoch 00048 | Train Acc: 0.8846 | Train Loss: 0.2969 | Valid Acc: 0.8846 | Valid loss: 0.2969 | Time: 0.0298
# Epoch 00049 | Train Acc: 0.8927 | Train Loss: 0.2827 | Valid Acc: 0.8927 | Valid loss: 0.2827 | Time: 0.0298
# Epoch 00050 | Train Acc: 0.9035 | Train Loss: 0.2669 | Valid Acc: 0.9035 | Valid loss: 0.2669 | Time: 0.0298
# Epoch 00051 | Train Acc: 0.9090 | Train Loss: 0.2525 | Valid Acc: 0.9090 | Valid loss: 0.2525 | Time: 0.0298
# Epoch 00052 | Train Acc: 0.9118 | Train Loss: 0.2399 | Valid Acc: 0.9118 | Valid loss: 0.2399 | Time: 0.0298
# Epoch 00053 | Train Acc: 0.9182 | Train Loss: 0.2263 | Valid Acc: 0.9182 | Valid loss: 0.2263 | Time: 0.0298
# Epoch 00054 | Train Acc: 0.9224 | Train Loss: 0.2134 | Valid Acc: 0.9224 | Valid loss: 0.2134 | Time: 0.0298
# Epoch 00055 | Train Acc: 0.9260 | Train Loss: 0.2028 | Valid Acc: 0.9260 | Valid loss: 0.2028 | Time: 0.0298
# Epoch 00056 | Train Acc: 0.9293 | Train Loss: 0.1935 | Valid Acc: 0.9293 | Valid loss: 0.1935 | Time: 0.0298
# Epoch 00057 | Train Acc: 0.9330 | Train Loss: 0.1835 | Valid Acc: 0.9330 | Valid loss: 0.1835 | Time: 0.0297
# Epoch 00058 | Train Acc: 0.9376 | Train Loss: 0.1743 | Valid Acc: 0.9376 | Valid loss: 0.1743 | Time: 0.0297
# Epoch 00059 | Train Acc: 0.9395 | Train Loss: 0.1668 | Valid Acc: 0.9395 | Valid loss: 0.1668 | Time: 0.0297
# Epoch 00060 | Train Acc: 0.9412 | Train Loss: 0.1609 | Valid Acc: 0.9412 | Valid loss: 0.1609 | Time: 0.0297
# Epoch 00061 | Train Acc: 0.9425 | Train Loss: 0.1551 | Valid Acc: 0.9425 | Valid loss: 0.1551 | Time: 0.0297
# Epoch 00062 | Train Acc: 0.9446 | Train Loss: 0.1492 | Valid Acc: 0.9446 | Valid loss: 0.1492 | Time: 0.0297
# Epoch 00063 | Train Acc: 0.9459 | Train Loss: 0.1437 | Valid Acc: 0.9459 | Valid loss: 0.1437 | Time: 0.0297
# Epoch 00064 | Train Acc: 0.9477 | Train Loss: 0.1393 | Valid Acc: 0.9477 | Valid loss: 0.1393 | Time: 0.0297
# Epoch 00065 | Train Acc: 0.9485 | Train Loss: 0.1359 | Valid Acc: 0.9485 | Valid loss: 0.1359 | Time: 0.0297
# Epoch 00066 | Train Acc: 0.9498 | Train Loss: 0.1329 | Valid Acc: 0.9498 | Valid loss: 0.1329 | Time: 0.0297
# Epoch 00067 | Train Acc: 0.9508 | Train Loss: 0.1296 | Valid Acc: 0.9508 | Valid loss: 0.1296 | Time: 0.0296
# Epoch 00068 | Train Acc: 0.9520 | Train Loss: 0.1262 | Valid Acc: 0.9520 | Valid loss: 0.1262 | Time: 0.0297
# Epoch 00069 | Train Acc: 0.9530 | Train Loss: 0.1236 | Valid Acc: 0.9530 | Valid loss: 0.1236 | Time: 0.0298
# Epoch 00070 | Train Acc: 0.9533 | Train Loss: 0.1216 | Valid Acc: 0.9533 | Valid loss: 0.1216 | Time: 0.0299
# Epoch 00071 | Train Acc: 0.9539 | Train Loss: 0.1198 | Valid Acc: 0.9539 | Valid loss: 0.1198 | Time: 0.0299
# Epoch 00072 | Train Acc: 0.9544 | Train Loss: 0.1178 | Valid Acc: 0.9544 | Valid loss: 0.1178 | Time: 0.0300
# Epoch 00073 | Train Acc: 0.9550 | Train Loss: 0.1158 | Valid Acc: 0.9550 | Valid loss: 0.1158 | Time: 0.0300
# Epoch 00074 | Train Acc: 0.9554 | Train Loss: 0.1140 | Valid Acc: 0.9554 | Valid loss: 0.1140 | Time: 0.0300
# Epoch 00075 | Train Acc: 0.9556 | Train Loss: 0.1126 | Valid Acc: 0.9556 | Valid loss: 0.1126 | Time: 0.0300
# Epoch 00076 | Train Acc: 0.9561 | Train Loss: 0.1115 | Valid Acc: 0.9561 | Valid loss: 0.1115 | Time: 0.0300
# Epoch 00077 | Train Acc: 0.9567 | Train Loss: 0.1104 | Valid Acc: 0.9567 | Valid loss: 0.1104 | Time: 0.0300
# Epoch 00078 | Train Acc: 0.9568 | Train Loss: 0.1093 | Valid Acc: 0.9568 | Valid loss: 0.1093 | Time: 0.0300
# Epoch 00079 | Train Acc: 0.9571 | Train Loss: 0.1081 | Valid Acc: 0.9571 | Valid loss: 0.1081 | Time: 0.0300
# Epoch 00080 | Train Acc: 0.9576 | Train Loss: 0.1069 | Valid Acc: 0.9576 | Valid loss: 0.1069 | Time: 0.0300
# Epoch 00081 | Train Acc: 0.9579 | Train Loss: 0.1058 | Valid Acc: 0.9579 | Valid loss: 0.1058 | Time: 0.0300
# Epoch 00082 | Train Acc: 0.9581 | Train Loss: 0.1048 | Valid Acc: 0.9581 | Valid loss: 0.1048 | Time: 0.0300
# Epoch 00083 | Train Acc: 0.9583 | Train Loss: 0.1040 | Valid Acc: 0.9583 | Valid loss: 0.1040 | Time: 0.0300
# Epoch 00084 | Train Acc: 0.9585 | Train Loss: 0.1033 | Valid Acc: 0.9585 | Valid loss: 0.1033 | Time: 0.0300
# Epoch 00085 | Train Acc: 0.9587 | Train Loss: 0.1027 | Valid Acc: 0.9587 | Valid loss: 0.1027 | Time: 0.0300
# Epoch 00086 | Train Acc: 0.9587 | Train Loss: 0.1023 | Valid Acc: 0.9587 | Valid loss: 0.1023 | Time: 0.0300
# Epoch 00087 | Train Acc: 0.9578 | Train Loss: 0.1023 | Valid Acc: 0.9578 | Valid loss: 0.1023 | Time: 0.0300
# Epoch 00088 | Train Acc: 0.9581 | Train Loss: 0.1023 | Valid Acc: 0.9581 | Valid loss: 0.1023 | Time: 0.0301
# Epoch 00089 | Train Acc: 0.9580 | Train Loss: 0.1016 | Valid Acc: 0.9580 | Valid loss: 0.1016 | Time: 0.0302
# Epoch 00090 | Train Acc: 0.9588 | Train Loss: 0.1001 | Valid Acc: 0.9588 | Valid loss: 0.1001 | Time: 0.0303
# Epoch 00091 | Train Acc: 0.9597 | Train Loss: 0.0991 | Valid Acc: 0.9597 | Valid loss: 0.0991 | Time: 0.0303
# Epoch 00092 | Train Acc: 0.9598 | Train Loss: 0.0986 | Valid Acc: 0.9598 | Valid loss: 0.0986 | Time: 0.0303
# Epoch 00093 | Train Acc: 0.9600 | Train Loss: 0.0987 | Valid Acc: 0.9600 | Valid loss: 0.0987 | Time: 0.0303
# Epoch 00094 | Train Acc: 0.9598 | Train Loss: 0.0989 | Valid Acc: 0.9598 | Valid loss: 0.0989 | Time: 0.0303
# Epoch 00095 | Train Acc: 0.9599 | Train Loss: 0.0985 | Valid Acc: 0.9599 | Valid loss: 0.0985 | Time: 0.0304
# Epoch 00096 | Train Acc: 0.9601 | Train Loss: 0.0974 | Valid Acc: 0.9601 | Valid loss: 0.0974 | Time: 0.0304
# Epoch 00097 | Train Acc: 0.9601 | Train Loss: 0.0965 | Valid Acc: 0.9601 | Valid loss: 0.0965 | Time: 0.0304
# Epoch 00098 | Train Acc: 0.9602 | Train Loss: 0.0961 | Valid Acc: 0.9602 | Valid loss: 0.0961 | Time: 0.0304
# Epoch 00099 | Train Acc: 0.9620 | Train Loss: 0.0960 | Valid Acc: 0.9620 | Valid loss: 0.0960 | Time: 0.0304
#
# Test Acc: 0.7553 | Test loss: 4.7771

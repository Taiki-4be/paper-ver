# %%
from collections import defaultdict
import argparse
import torch as th
import torch.nn as nn
import torch.nn.functional as F
import dgl
import dgl.function as fn
import dgl.nn as dglnn
import tqdm
import pandas as pd
import numpy as np
import random as rd
import time
# Out:
# Using backend: pytorch

# %%
parser = argparse.ArgumentParser(description='RGCN')
parser.add_argument("--dropout", type=float, default=0,
        help="dropout probability")
parser.add_argument("--n-hidden", type=int, default=16,
        help="number of hidden units")
parser.add_argument("--gpu", type=int, default=-1,
        help="gpu")
parser.add_argument("--lr", type=float, default=1e-2,
        help="learning rate")
parser.add_argument("--n-bases", type=int, default=-1,
        help="number of filter weight matrices, default: -1 [use all]")
parser.add_argument("--n-layers", type=int, default=2,
        help="number of propagation rounds")
parser.add_argument("-e", "--n-epochs", type=int, default=50,
        help="number of training epochs")
parser.add_argument("--model_path", type=str, default=None,
        help='path for save the model')
parser.add_argument("--l2norm", type=float, default=0,
        help="l2 norm coef")
parser.add_argument("--use-self-loop", default=False, action='store_true',
        help="include self feature as a special relation")
fp = parser.add_mutually_exclusive_group(required=False)
fp.add_argument('--validation', dest='validation', action='store_true')
fp.add_argument('--testing', dest='validation', action='store_false')
parser.set_defaults(validation=True)

args = parser.parse_args(args=['-e','100','--n-layers','5','--testing','--gpu','0'])

# %% [markdown]
# ### CSVファイルからテンソルへの変換
# daskというライブラリを経由して、テンソルへと変換
# daskは大きなデータを扱う際にアシストしてくれるもの。学習の際に、サイズが大きいものをうまく扱う？
# ```
# import dask.dataframe as dd
# print("Loading CSV...")
# test = dd.read_csv("position-pass-position.csv", encoding = "UTF-8")
#
# print("Converting to Tensor...")
# test_tensor = th.tensor(test)
# ```

# %% [markdown]
# ### うまく行かなったのPandasで

# %% [markdown]
# ### グラフの構築
# 作ったテンソルをDGLに読み込ませるだけ

# %%
rel = pd.read_csv('data\STN\data.csv')
id = pd.read_csv('data\STN\list.csv')
pos_null = pd.read_csv('data\STN\pn.csv')
null_pos = pd.read_csv('data\STN\_np.csv')
t_link = pd.read_csv('data\STN\link.csv')
mini = pd.read_csv('data\STN\mini\list.csv')

# %%
graphdata = {
    ('position', 'pass','position'):(th.tensor(rel['fromid']),th.tensor(rel['toid'])),
    ('position','temporal','position'):(th.tensor(t_link['fromid']),th.tensor(t_link['toid'])),
    ('position','temporal','null'):(th.tensor(pos_null['fromid']),th.tensor(pos_null['nullid'])),
    ('null','temporal','position'):(th.tensor(null_pos['nullid']),th.tensor(null_pos['toid']))
}
g = dgl.heterograph(graphdata)

# %%
#label数８
labels = th.tensor(id['8pos'])
num_classes = 8 #len(g.ntypes)
"""
#label数４
labels = th.tensor(id['newpos'])
num_classes = 4 #len(g.ntypes)
"""
"""
#label数２５
labels = th.tensor(id['posid'])
num_classes = 25 #len(g.ntypes)

"""
# Out:
# "\n#label数２５\nlabels = th.tensor(id['posid'])\nnum_classes = 25 #len(g.ntypes)\n\n"

# %%
category = 'position'
mask_wt = 0.7
final_num = len(mini)
num_node = g.num_nodes(category) - final_num

mask = [1] * int(num_node * mask_wt) + [0] * (num_node - int(num_node * mask_wt))
rd.shuffle(mask)
mask = mask + [0] * final_num

mask_wt = 0.2
mask_tr = [1] * int(final_num * mask_wt) + [0] * (final_num - int(final_num * mask_wt))
rd.shuffle(mask_tr)
mask_tr = [0] * (num_node - final_num) + mask_tr

train_mask = th.tensor(mask)
test_mask = th.tensor(mask_tr)
train_idx = th.nonzero(train_mask, as_tuple=False).squeeze()
test_idx = th.nonzero(test_mask, as_tuple=False).squeeze()
category_id = category
for i, ntype in enumerate(g.ntypes):
    if ntype == category:
        category_id = i

# %% [markdown]
# ### モデルの定義
# 今回はサンプルコードの中から`RelGraphConv`を引用する。使わないやつごと引用した

# %%
class RelGraphConvLayer(nn.Module):
    r"""Relational graph convolution layer.

    Parameters
    ----------
    in_feat : int
        Input feature size.
    out_feat : int
        Output feature size.
    rel_names : list[str]
        Relation names.
    num_bases : int, optional
        Number of bases. If is none, use number of relations. Default: None.
    weight : bool, optional
        True if a linear layer is applied after message passing. Default: True
    bias : bool, optional
        True if bias is added. Default: True
    activation : callable, optional
        Activation function. Default: None
    self_loop : bool, optional
        True to include self loop message. Default: False
    dropout : float, optional
        Dropout rate. Default: 0.0
    """
    def __init__(self,
                 in_feat,
                 out_feat,
                 rel_names,
                 num_bases,
                 *,
                 weight=True,
                 bias=True,
                 activation=None,
                 self_loop=False,
                 dropout=0.0):
        super(RelGraphConvLayer, self).__init__()
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.rel_names = rel_names
        self.num_bases = num_bases
        self.bias = bias
        self.activation = activation
        self.self_loop = self_loop

        self.conv = dglnn.HeteroGraphConv({
                rel : dglnn.GraphConv(in_feat, out_feat, norm='right', weight=False, bias=False)
                for rel in rel_names
            })

        self.use_weight = weight
        self.use_basis = num_bases < len(self.rel_names) and weight
        if self.use_weight:
            if self.use_basis:
                self.basis = dglnn.WeightBasis((in_feat, out_feat), num_bases, len(self.rel_names))
            else:
                self.weight = nn.Parameter(th.Tensor(len(self.rel_names), in_feat, out_feat))
                nn.init.xavier_uniform_(self.weight, gain=nn.init.calculate_gain('relu'))

        # bias
        if bias:
            self.h_bias = nn.Parameter(th.Tensor(out_feat))
            nn.init.zeros_(self.h_bias)

        # weight for self loop
        if self.self_loop:
            self.loop_weight = nn.Parameter(th.Tensor(in_feat, out_feat))
            nn.init.xavier_uniform_(self.loop_weight,
                                    gain=nn.init.calculate_gain('relu'))

        self.dropout = nn.Dropout(dropout)

    def forward(self, g, inputs):
        """Forward computation

        Parameters
        ----------
        g : DGLHeteroGraph
            Input graph.
        inputs : dict[str, torch.Tensor]
            Node feature for each node type.

        Returns
        -------
        dict[str, torch.Tensor]
            New node features for each node type.
        """
        g = g.local_var()
        if self.use_weight:
            weight = self.basis() if self.use_basis else self.weight
            wdict = {self.rel_names[i] : {'weight' : w.squeeze(0)}
                     for i, w in enumerate(th.split(weight, 1, dim=0))}
        else:
            wdict = {}

        if g.is_block:
            inputs_src = inputs
            inputs_dst = {k: v[:g.number_of_dst_nodes(k)] for k, v in inputs.items()}
        else:
            inputs_src = inputs_dst = inputs

        hs = self.conv(g, inputs, mod_kwargs=wdict)

        def _apply(ntype, h):
            if self.self_loop:
                h = h + th.matmul(inputs_dst[ntype], self.loop_weight)
            if self.bias:
                h = h + self.h_bias
            if self.activation:
                h = self.activation(h)
            return self.dropout(h)
        return {ntype : _apply(ntype, h) for ntype, h in hs.items()}

# %%
class RelGraphConvLayerHeteroAPI(nn.Module):
    r"""Relational graph convolution layer.

    Parameters
    ----------
    in_feat : int
        Input feature size.
    out_feat : int
        Output feature size.
    rel_names : list[str]
        Relation names.
    num_bases : int, optional
        Number of bases. If is none, use number of relations. Default: None.
    weight : bool, optional
        True if a linear layer is applied after message passing. Default: True
    bias : bool, optional
        True if bias is added. Default: True
    activation : callable, optional
        Activation function. Default: None
    self_loop : bool, optional
        True to include self loop message. Default: False
    dropout : float, optional
        Dropout rate. Default: 0.0
    """
    def __init__(self,
                 in_feat,
                 out_feat,
                 rel_names,
                 num_bases,
                 *,
                 weight=True,
                 bias=True,
                 activation=None,
                 self_loop=False,
                 dropout=0.0):
        super(RelGraphConvLayerHeteroAPI, self).__init__()
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.rel_names = rel_names
        self.num_bases = num_bases
        self.bias = bias
        self.activation = activation
        self.self_loop = self_loop

        self.use_weight = weight
        self.use_basis = num_bases < len(self.rel_names) and weight
        if self.use_weight:
            if self.use_basis:
                self.basis = dglnn.WeightBasis((in_feat, out_feat), num_bases, len(self.rel_names))
            else:
                self.weight = nn.Parameter(th.Tensor(len(self.rel_names), in_feat, out_feat))
                nn.init.xavier_uniform_(self.weight, gain=nn.init.calculate_gain('relu'))

        # bias
        if bias:
            self.h_bias = nn.Parameter(th.Tensor(out_feat))
            nn.init.zeros_(self.h_bias)

        # weight for self loop
        if self.self_loop:
            self.loop_weight = nn.Parameter(th.Tensor(in_feat, out_feat))
            nn.init.xavier_uniform_(self.loop_weight,
                                    gain=nn.init.calculate_gain('relu'))

        self.dropout = nn.Dropout(dropout)

    def forward(self, g, inputs):
        """Forward computation

        Parameters
        ----------
        g : DGLHeteroGraph
            Input graph.
        inputs : dict[str, torch.Tensor]
            Node feature for each node type.

        Returns
        -------
        dict[str, torch.Tensor]
            New node features for each node type.
        """
        g = g.local_var()
        if self.use_weight:
            weight = self.basis() if self.use_basis else self.weight
            wdict = {self.rel_names[i] : {'weight' : w.squeeze(0)}
                     for i, w in enumerate(th.split(weight, 1, dim=0))}
        else:
            wdict = {}

        inputs_src = inputs_dst = inputs

        for srctype,_,_ in g.canonical_etypes:
            g.nodes[srctype].data['h'] = inputs[srctype]

        if self.use_weight:
            g.apply_edges(fn.copy_u('h', 'm'))
            m = g.edata['m']
            for rel in g.canonical_etypes:
                _, etype, _ = rel
                g.edges[rel].data['h*w_r'] =  th.matmul(m[rel], wdict[etype]['weight'])
        else:
            g.apply_edges(fn.copy_u('h', 'h*w_r'))

        g.update_all(fn.copy_e('h*w_r', 'm'), fn.sum('m', 'h'))

        def _apply(ntype):
            h = g.nodes[ntype].data['h']
            if self.self_loop:
                h = h + th.matmul(inputs_dst[ntype], self.loop_weight)
            if self.bias:
                h = h + self.h_bias
            if self.activation:
                h = self.activation(h)
            return self.dropout(h)
        return {ntype : _apply(ntype) for ntype in g.dsttypes}

# %%
class RelGraphEmbed(nn.Module):
    r"""Embedding layer for featureless heterograph."""
    def __init__(self,
                 g,
                 embed_size,
                 embed_name='embed',
                 activation=None,
                 dropout=0.0):
        super(RelGraphEmbed, self).__init__()
        self.g = g
        self.embed_size = embed_size
        self.embed_name = embed_name
        self.activation = activation
        self.dropout = nn.Dropout(dropout)

        # create weight embeddings for each node for each relation
        self.embeds = nn.ParameterDict()
        for ntype in g.ntypes:
            embed = nn.Parameter(th.Tensor(g.number_of_nodes(ntype), self.embed_size))
            nn.init.xavier_uniform_(embed, gain=nn.init.calculate_gain('relu'))
            self.embeds[ntype] = embed

    def forward(self, block=None):
        """Forward computation

        Parameters
        ----------
        block : DGLHeteroGraph, optional
            If not specified, directly return the full graph with embeddings stored in
            :attr:`embed_name`. Otherwise, extract and store the embeddings to the block
            graph and return.

        Returns
        -------
        DGLHeteroGraph
            The block graph fed with embeddings.
        """
        return self.embeds

# %%
class EntityClassify(nn.Module):
    def __init__(self,
                 g,
                 h_dim, out_dim,
                 num_bases,
                 num_hidden_layers=1,
                 dropout=0,
                 use_self_loop=False):
        super(EntityClassify, self).__init__()
        self.g = g
        self.h_dim = h_dim
        self.out_dim = out_dim
        self.rel_names = list(set(g.etypes))
        self.rel_names.sort()
        if num_bases < 0 or num_bases > len(self.rel_names):
            self.num_bases = len(self.rel_names)
        else:
            self.num_bases = num_bases
        self.num_hidden_layers = num_hidden_layers
        self.dropout = dropout
        self.use_self_loop = use_self_loop

        self.embed_layer = RelGraphEmbed(g, self.h_dim)
        self.layers = nn.ModuleList()
        # i2h
        self.layers.append(RelGraphConvLayer(
            self.h_dim, self.h_dim, self.rel_names,
            self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
            dropout=self.dropout, weight=False))
        # h2h
        for i in range(self.num_hidden_layers):
            self.layers.append(RelGraphConvLayer(
                self.h_dim, self.h_dim, self.rel_names,
                self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
                dropout=self.dropout))
        # h2o
        self.layers.append(RelGraphConvLayer(
            self.h_dim, self.out_dim, self.rel_names,
            self.num_bases, activation=None,
            self_loop=self.use_self_loop))

    def forward(self, h=None, blocks=None):
        if h is None:
            # full graph training
            h = self.embed_layer()
        if blocks is None:
            # full graph training
            for layer in self.layers:
                h = layer(self.g, h)
        else:
            # minibatch training
            for layer, block in zip(self.layers, blocks):
                h = layer(block, h)
        return h

    def inference(self, g, batch_size, device, num_workers, x=None):
        """Minibatch inference of final representation over all node types.

        ***NOTE***
        For node classification, the model is trained to predict on only one node type's
        label.  Therefore, only that type's final representation is meaningful.
        """

        if x is None:
            x = self.embed_layer()

        for l, layer in enumerate(self.layers):
            y = {
                k: th.zeros(
                    g.number_of_nodes(k),
                    self.h_dim if l != len(self.layers) - 1 else self.out_dim)
                for k in g.ntypes}

            sampler = dgl.dataloading.MultiLayerFullNeighborSampler(1)
            dataloader = dgl.dataloading.NodeDataLoader(
                g,
                {k: th.arange(g.number_of_nodes(k)) for k in g.ntypes},
                sampler,
                batch_size=batch_size,
                shuffle=True,
                drop_last=False,
                num_workers=num_workers)

            for input_nodes, output_nodes, blocks in tqdm.tqdm(dataloader):
                block = blocks[0].to(device)

                h = {k: x[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
                h = layer(block, h)

                for k in h.keys():
                    y[k][output_nodes[k]] = h[k].cpu()

            x = y
        return y

# %%
class EntityClassify_HeteroAPI(nn.Module):
    def __init__(self,
                 g,
                 h_dim, out_dim,
                 num_bases,
                 num_hidden_layers=1,
                 dropout=0,
                 use_self_loop=False):
        super(EntityClassify_HeteroAPI, self).__init__()
        self.g = g
        self.h_dim = h_dim
        self.out_dim = out_dim
        self.rel_names = list(set(g.etypes))
        self.rel_names.sort()
        if num_bases < 0 or num_bases > len(self.rel_names):
            self.num_bases = len(self.rel_names)
        else:
            self.num_bases = num_bases
        self.num_hidden_layers = num_hidden_layers
        self.dropout = dropout
        self.use_self_loop = use_self_loop

        self.embed_layer = RelGraphEmbed(g, self.h_dim)
        self.layers = nn.ModuleList()
        # i2h
        self.layers.append(RelGraphConvLayerHeteroAPI(
            self.h_dim, self.h_dim, self.rel_names,
            self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
            dropout=self.dropout, weight=False))
        # h2h
        for i in range(self.num_hidden_layers):
            self.layers.append(RelGraphConvLayerHeteroAPI(
                self.h_dim, self.h_dim, self.rel_names,
                self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
                dropout=self.dropout))
        # h2o
        self.layers.append(RelGraphConvLayerHeteroAPI(
            self.h_dim, self.out_dim, self.rel_names,
            self.num_bases, activation=None,
            self_loop=self.use_self_loop))

    def forward(self, h=None, blocks=None):
        if h is None:
            # full graph training
            h = self.embed_layer()
        if blocks is None:
            # full graph training
            for layer in self.layers:
                h = layer(self.g, h)
        else:
            # minibatch training
            for layer, block in zip(self.layers, blocks):
                h = layer(block, h)
        return h

    def inference(self, g, batch_size, device, num_workers, x=None):
        """Minibatch inference of final representation over all node types.

        ***NOTE***
        For node classification, the model is trained to predict on only one node type's
        label.  Therefore, only that type's final representation is meaningful.
        """

        if x is None:
            x = self.embed_layer()

        for l, layer in enumerate(self.layers):
            y = {
                k: th.zeros(
                    g.number_of_nodes(k),
                    self.h_dim if l != len(self.layers) - 1 else self.out_dim)
                for k in g.ntypes}

            sampler = dgl.dataloading.MultiLayerFullNeighborSampler(1)
            dataloader = dgl.dataloading.NodeDataLoader(
                g,
                {k: th.arange(g.number_of_nodes(k)) for k in g.ntypes},
                sampler,
                batch_size=batch_size,
                shuffle=True,
                drop_last=False,
                num_workers=num_workers)

            for input_nodes, output_nodes, blocks in tqdm.tqdm(dataloader):
                block = blocks[0].to(device)

                h = {k: x[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
                h = layer(block, h)

                for k in h.keys():
                    y[k][output_nodes[k]] = h[k].cpu()

            x = y
        return y

# %% [markdown]
# ### ノード分類の実装
# ここから作ったグラフを使って学習を行う。

# %%
# split dataset into train, validate, test
if args.validation:
    val_idx = train_idx[:len(train_idx) // 5]
    train_idx = train_idx[len(train_idx) // 5:]
else:
    val_idx = train_idx

# %%
# check cuda
use_cuda = args.gpu >= 0 and th.cuda.is_available()
if use_cuda:
    th.cuda.set_device(args.gpu)
    g = g.to('cuda:%d' % args.gpu)
    labels = labels.cuda()
    train_idx = train_idx.cuda()
    test_idx = test_idx.cuda()

# %%
# create model
model = EntityClassify(g,
                       args.n_hidden,
                       num_classes,
                       num_bases=args.n_bases,
                       num_hidden_layers=args.n_layers - 2,
                       dropout=args.dropout,
                       use_self_loop=args.use_self_loop)

# %%
if use_cuda:
        model.cuda()

# %%
# optimizer
optimizer = th.optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.l2norm)

# %%
# training loop
print("start training...")
dur = []
model.train()
for epoch in range(args.n_epochs):
    optimizer.zero_grad()
    if epoch > 5:
        t0 = time.time()
    logits = model()[category]
    loss = F.cross_entropy(logits[train_idx], labels[train_idx])
    loss.backward()
    optimizer.step()
    t1 = time.time()

    if epoch > 5:
        dur.append(t1 - t0)
    train_acc = th.sum(logits[train_idx].argmax(dim=1) == labels[train_idx]).item() / len(train_idx)
    val_loss = F.cross_entropy(logits[val_idx], labels[val_idx])
    val_acc = th.sum(logits[val_idx].argmax(dim=1) == labels[val_idx]).item() / len(val_idx)
    print("Epoch {:05d} | Train Acc: {:.4f} | Train Loss: {:.4f} | Valid Acc: {:.4f} | Valid loss: {:.4f} | Time: {:.4f}".
         format(epoch, train_acc, loss.item(), val_acc, val_loss.item(), np.average(dur)))
print()
if args.model_path is not None:
    th.save(model.state_dict(), args.model_path)

model.eval()
logits = model.forward()[category]
test_loss = F.cross_entropy(logits[test_idx], labels[test_idx])
test_acc = th.sum(logits[test_idx].argmax(dim=1) == labels[test_idx]).item() / len(test_idx)
print("Test Acc: {:.4f} | Test loss: {:.4f}".format(test_acc, test_loss.item()))
print()
# Out:
# start training...
# C:\Users\Taiki\anaconda3\envs\thrgcn\lib\site-packages\numpy\lib\function_base.py:392: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\Taiki\anaconda3\envs\thrgcn\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Epoch 00000 | Train Acc: 0.1409 | Train Loss: 2.0794 | Valid Acc: 0.1409 | Valid loss: 2.0794 | Time: nan
# Epoch 00001 | Train Acc: 0.1984 | Train Loss: 2.0727 | Valid Acc: 0.1984 | Valid loss: 2.0727 | Time: nan
# Epoch 00002 | Train Acc: 0.2013 | Train Loss: 2.0640 | Valid Acc: 0.2013 | Valid loss: 2.0640 | Time: nan
# Epoch 00003 | Train Acc: 0.2028 | Train Loss: 2.0524 | Valid Acc: 0.2028 | Valid loss: 2.0524 | Time: nan
# Epoch 00004 | Train Acc: 0.2035 | Train Loss: 2.0374 | Valid Acc: 0.2035 | Valid loss: 2.0374 | Time: nan
# Epoch 00005 | Train Acc: 0.2044 | Train Loss: 2.0191 | Valid Acc: 0.2044 | Valid loss: 2.0191 | Time: nan
# Epoch 00006 | Train Acc: 0.2073 | Train Loss: 2.0002 | Valid Acc: 0.2073 | Valid loss: 2.0002 | Time: 0.0290
# Epoch 00007 | Train Acc: 0.2110 | Train Loss: 1.9899 | Valid Acc: 0.2110 | Valid loss: 1.9899 | Time: 0.0290
# Epoch 00008 | Train Acc: 0.2131 | Train Loss: 1.9865 | Valid Acc: 0.2131 | Valid loss: 1.9865 | Time: 0.0293
# Epoch 00009 | Train Acc: 0.2134 | Train Loss: 1.9726 | Valid Acc: 0.2134 | Valid loss: 1.9726 | Time: 0.0295
# Epoch 00010 | Train Acc: 0.2153 | Train Loss: 1.9563 | Valid Acc: 0.2153 | Valid loss: 1.9563 | Time: 0.0297
# Epoch 00011 | Train Acc: 0.2206 | Train Loss: 1.9421 | Valid Acc: 0.2206 | Valid loss: 1.9421 | Time: 0.0298
# Epoch 00012 | Train Acc: 0.2323 | Train Loss: 1.9280 | Valid Acc: 0.2323 | Valid loss: 1.9280 | Time: 0.0298
# Epoch 00013 | Train Acc: 0.2423 | Train Loss: 1.9113 | Valid Acc: 0.2423 | Valid loss: 1.9113 | Time: 0.0297
# Epoch 00014 | Train Acc: 0.2504 | Train Loss: 1.8906 | Valid Acc: 0.2504 | Valid loss: 1.8906 | Time: 0.0297
# Epoch 00015 | Train Acc: 0.2557 | Train Loss: 1.8659 | Valid Acc: 0.2557 | Valid loss: 1.8659 | Time: 0.0298
# Epoch 00016 | Train Acc: 0.2601 | Train Loss: 1.8390 | Valid Acc: 0.2601 | Valid loss: 1.8390 | Time: 0.0298
# Epoch 00017 | Train Acc: 0.2649 | Train Loss: 1.8118 | Valid Acc: 0.2649 | Valid loss: 1.8118 | Time: 0.0297
# Epoch 00018 | Train Acc: 0.2709 | Train Loss: 1.7836 | Valid Acc: 0.2709 | Valid loss: 1.7836 | Time: 0.0297
# Epoch 00019 | Train Acc: 0.2825 | Train Loss: 1.7512 | Valid Acc: 0.2825 | Valid loss: 1.7512 | Time: 0.0296
# Epoch 00020 | Train Acc: 0.2995 | Train Loss: 1.7150 | Valid Acc: 0.2995 | Valid loss: 1.7150 | Time: 0.0296
# Epoch 00021 | Train Acc: 0.3308 | Train Loss: 1.6782 | Valid Acc: 0.3308 | Valid loss: 1.6782 | Time: 0.0297
# Epoch 00022 | Train Acc: 0.3597 | Train Loss: 1.6406 | Valid Acc: 0.3597 | Valid loss: 1.6406 | Time: 0.0296
# Epoch 00023 | Train Acc: 0.3792 | Train Loss: 1.5995 | Valid Acc: 0.3792 | Valid loss: 1.5995 | Time: 0.0295
# Epoch 00024 | Train Acc: 0.3950 | Train Loss: 1.5546 | Valid Acc: 0.3950 | Valid loss: 1.5546 | Time: 0.0296
# Epoch 00025 | Train Acc: 0.4099 | Train Loss: 1.5091 | Valid Acc: 0.4099 | Valid loss: 1.5091 | Time: 0.0295
# Epoch 00026 | Train Acc: 0.4237 | Train Loss: 1.4633 | Valid Acc: 0.4237 | Valid loss: 1.4633 | Time: 0.0295
# Epoch 00027 | Train Acc: 0.4480 | Train Loss: 1.4137 | Valid Acc: 0.4480 | Valid loss: 1.4137 | Time: 0.0295
# Epoch 00028 | Train Acc: 0.4728 | Train Loss: 1.3629 | Valid Acc: 0.4728 | Valid loss: 1.3629 | Time: 0.0296
# Epoch 00029 | Train Acc: 0.4970 | Train Loss: 1.3133 | Valid Acc: 0.4970 | Valid loss: 1.3133 | Time: 0.0295
# Epoch 00030 | Train Acc: 0.5167 | Train Loss: 1.2645 | Valid Acc: 0.5167 | Valid loss: 1.2645 | Time: 0.0295
# Epoch 00031 | Train Acc: 0.5336 | Train Loss: 1.2156 | Valid Acc: 0.5336 | Valid loss: 1.2156 | Time: 0.0295
# Epoch 00032 | Train Acc: 0.5515 | Train Loss: 1.1671 | Valid Acc: 0.5515 | Valid loss: 1.1671 | Time: 0.0295
# Epoch 00033 | Train Acc: 0.5721 | Train Loss: 1.1173 | Valid Acc: 0.5721 | Valid loss: 1.1173 | Time: 0.0295
# Epoch 00034 | Train Acc: 0.5876 | Train Loss: 1.0683 | Valid Acc: 0.5876 | Valid loss: 1.0683 | Time: 0.0295
# Epoch 00035 | Train Acc: 0.6111 | Train Loss: 1.0207 | Valid Acc: 0.6111 | Valid loss: 1.0207 | Time: 0.0298
# Epoch 00036 | Train Acc: 0.6253 | Train Loss: 0.9770 | Valid Acc: 0.6253 | Valid loss: 0.9770 | Time: 0.0299
# Epoch 00037 | Train Acc: 0.6335 | Train Loss: 0.9525 | Valid Acc: 0.6335 | Valid loss: 0.9525 | Time: 0.0299
# Epoch 00038 | Train Acc: 0.6387 | Train Loss: 0.9331 | Valid Acc: 0.6387 | Valid loss: 0.9331 | Time: 0.0299
# Epoch 00039 | Train Acc: 0.6737 | Train Loss: 0.8634 | Valid Acc: 0.6737 | Valid loss: 0.8634 | Time: 0.0299
# Epoch 00040 | Train Acc: 0.6679 | Train Loss: 0.8625 | Valid Acc: 0.6679 | Valid loss: 0.8625 | Time: 0.0299
# Epoch 00041 | Train Acc: 0.6967 | Train Loss: 0.8055 | Valid Acc: 0.6967 | Valid loss: 0.8055 | Time: 0.0299
# Epoch 00042 | Train Acc: 0.6947 | Train Loss: 0.8028 | Valid Acc: 0.6947 | Valid loss: 0.8028 | Time: 0.0299
# Epoch 00043 | Train Acc: 0.7182 | Train Loss: 0.7522 | Valid Acc: 0.7182 | Valid loss: 0.7522 | Time: 0.0299
# Epoch 00044 | Train Acc: 0.7169 | Train Loss: 0.7495 | Valid Acc: 0.7169 | Valid loss: 0.7495 | Time: 0.0299
# Epoch 00045 | Train Acc: 0.7413 | Train Loss: 0.7053 | Valid Acc: 0.7413 | Valid loss: 0.7053 | Time: 0.0299
# Epoch 00046 | Train Acc: 0.7433 | Train Loss: 0.6983 | Valid Acc: 0.7433 | Valid loss: 0.6983 | Time: 0.0298
# Epoch 00047 | Train Acc: 0.7586 | Train Loss: 0.6629 | Valid Acc: 0.7586 | Valid loss: 0.6629 | Time: 0.0298
# Epoch 00048 | Train Acc: 0.7616 | Train Loss: 0.6514 | Valid Acc: 0.7616 | Valid loss: 0.6514 | Time: 0.0298
# Epoch 00049 | Train Acc: 0.7755 | Train Loss: 0.6237 | Valid Acc: 0.7755 | Valid loss: 0.6237 | Time: 0.0297
# Epoch 00050 | Train Acc: 0.7833 | Train Loss: 0.6087 | Valid Acc: 0.7833 | Valid loss: 0.6087 | Time: 0.0298
# Epoch 00051 | Train Acc: 0.7911 | Train Loss: 0.5874 | Valid Acc: 0.7911 | Valid loss: 0.5874 | Time: 0.0298
# Epoch 00052 | Train Acc: 0.7967 | Train Loss: 0.5710 | Valid Acc: 0.7967 | Valid loss: 0.5710 | Time: 0.0298
# Epoch 00053 | Train Acc: 0.8054 | Train Loss: 0.5535 | Valid Acc: 0.8054 | Valid loss: 0.5535 | Time: 0.0297
# Epoch 00054 | Train Acc: 0.8121 | Train Loss: 0.5367 | Valid Acc: 0.8121 | Valid loss: 0.5367 | Time: 0.0297
# Epoch 00055 | Train Acc: 0.8177 | Train Loss: 0.5219 | Valid Acc: 0.8177 | Valid loss: 0.5219 | Time: 0.0297
# Epoch 00056 | Train Acc: 0.8238 | Train Loss: 0.5051 | Valid Acc: 0.8238 | Valid loss: 0.5051 | Time: 0.0297
# Epoch 00057 | Train Acc: 0.8284 | Train Loss: 0.4925 | Valid Acc: 0.8284 | Valid loss: 0.4925 | Time: 0.0297
# Epoch 00058 | Train Acc: 0.8358 | Train Loss: 0.4758 | Valid Acc: 0.8358 | Valid loss: 0.4758 | Time: 0.0298
# Epoch 00059 | Train Acc: 0.8401 | Train Loss: 0.4648 | Valid Acc: 0.8401 | Valid loss: 0.4648 | Time: 0.0297
# Epoch 00060 | Train Acc: 0.8452 | Train Loss: 0.4493 | Valid Acc: 0.8452 | Valid loss: 0.4493 | Time: 0.0297
# Epoch 00061 | Train Acc: 0.8481 | Train Loss: 0.4386 | Valid Acc: 0.8481 | Valid loss: 0.4386 | Time: 0.0297
# Epoch 00062 | Train Acc: 0.8546 | Train Loss: 0.4247 | Valid Acc: 0.8546 | Valid loss: 0.4247 | Time: 0.0297
# Epoch 00063 | Train Acc: 0.8592 | Train Loss: 0.4144 | Valid Acc: 0.8592 | Valid loss: 0.4144 | Time: 0.0297
# Epoch 00064 | Train Acc: 0.8640 | Train Loss: 0.4022 | Valid Acc: 0.8640 | Valid loss: 0.4022 | Time: 0.0297
# Epoch 00065 | Train Acc: 0.8676 | Train Loss: 0.3920 | Valid Acc: 0.8676 | Valid loss: 0.3920 | Time: 0.0297
# Epoch 00066 | Train Acc: 0.8716 | Train Loss: 0.3814 | Valid Acc: 0.8716 | Valid loss: 0.3814 | Time: 0.0297
# Epoch 00067 | Train Acc: 0.8755 | Train Loss: 0.3715 | Valid Acc: 0.8755 | Valid loss: 0.3715 | Time: 0.0297
# Epoch 00068 | Train Acc: 0.8793 | Train Loss: 0.3617 | Valid Acc: 0.8793 | Valid loss: 0.3617 | Time: 0.0296
# Epoch 00069 | Train Acc: 0.8824 | Train Loss: 0.3528 | Valid Acc: 0.8824 | Valid loss: 0.3528 | Time: 0.0296
# Epoch 00070 | Train Acc: 0.8849 | Train Loss: 0.3439 | Valid Acc: 0.8849 | Valid loss: 0.3439 | Time: 0.0296
# Epoch 00071 | Train Acc: 0.8869 | Train Loss: 0.3355 | Valid Acc: 0.8869 | Valid loss: 0.3355 | Time: 0.0297
# Epoch 00072 | Train Acc: 0.8896 | Train Loss: 0.3276 | Valid Acc: 0.8896 | Valid loss: 0.3276 | Time: 0.0296
# Epoch 00073 | Train Acc: 0.8912 | Train Loss: 0.3202 | Valid Acc: 0.8912 | Valid loss: 0.3202 | Time: 0.0297
# Epoch 00074 | Train Acc: 0.8940 | Train Loss: 0.3132 | Valid Acc: 0.8940 | Valid loss: 0.3132 | Time: 0.0297
# Epoch 00075 | Train Acc: 0.8965 | Train Loss: 0.3058 | Valid Acc: 0.8965 | Valid loss: 0.3058 | Time: 0.0296
# Epoch 00076 | Train Acc: 0.8989 | Train Loss: 0.2992 | Valid Acc: 0.8989 | Valid loss: 0.2992 | Time: 0.0297
# Epoch 00077 | Train Acc: 0.9016 | Train Loss: 0.2928 | Valid Acc: 0.9016 | Valid loss: 0.2928 | Time: 0.0297
# Epoch 00078 | Train Acc: 0.9026 | Train Loss: 0.2873 | Valid Acc: 0.9026 | Valid loss: 0.2873 | Time: 0.0297
# Epoch 00079 | Train Acc: 0.9045 | Train Loss: 0.2811 | Valid Acc: 0.9045 | Valid loss: 0.2811 | Time: 0.0297
# Epoch 00080 | Train Acc: 0.9062 | Train Loss: 0.2756 | Valid Acc: 0.9062 | Valid loss: 0.2756 | Time: 0.0296
# Epoch 00081 | Train Acc: 0.9082 | Train Loss: 0.2703 | Valid Acc: 0.9082 | Valid loss: 0.2703 | Time: 0.0297
# Epoch 00082 | Train Acc: 0.9092 | Train Loss: 0.2656 | Valid Acc: 0.9092 | Valid loss: 0.2656 | Time: 0.0296
# Epoch 00083 | Train Acc: 0.9106 | Train Loss: 0.2608 | Valid Acc: 0.9106 | Valid loss: 0.2608 | Time: 0.0296
# Epoch 00084 | Train Acc: 0.9118 | Train Loss: 0.2562 | Valid Acc: 0.9118 | Valid loss: 0.2562 | Time: 0.0296
# Epoch 00085 | Train Acc: 0.9134 | Train Loss: 0.2519 | Valid Acc: 0.9134 | Valid loss: 0.2519 | Time: 0.0296
# Epoch 00086 | Train Acc: 0.9144 | Train Loss: 0.2479 | Valid Acc: 0.9144 | Valid loss: 0.2479 | Time: 0.0296
# Epoch 00087 | Train Acc: 0.9153 | Train Loss: 0.2440 | Valid Acc: 0.9153 | Valid loss: 0.2440 | Time: 0.0296
# Epoch 00088 | Train Acc: 0.9164 | Train Loss: 0.2402 | Valid Acc: 0.9164 | Valid loss: 0.2402 | Time: 0.0296
# Epoch 00089 | Train Acc: 0.9177 | Train Loss: 0.2367 | Valid Acc: 0.9177 | Valid loss: 0.2367 | Time: 0.0296
# Epoch 00090 | Train Acc: 0.9186 | Train Loss: 0.2333 | Valid Acc: 0.9186 | Valid loss: 0.2333 | Time: 0.0296
# Epoch 00091 | Train Acc: 0.9194 | Train Loss: 0.2303 | Valid Acc: 0.9194 | Valid loss: 0.2303 | Time: 0.0296
# Epoch 00092 | Train Acc: 0.9204 | Train Loss: 0.2272 | Valid Acc: 0.9204 | Valid loss: 0.2272 | Time: 0.0297
# Epoch 00093 | Train Acc: 0.9212 | Train Loss: 0.2244 | Valid Acc: 0.9212 | Valid loss: 0.2244 | Time: 0.0297
# Epoch 00094 | Train Acc: 0.9221 | Train Loss: 0.2216 | Valid Acc: 0.9221 | Valid loss: 0.2216 | Time: 0.0297
# Epoch 00095 | Train Acc: 0.9227 | Train Loss: 0.2191 | Valid Acc: 0.9227 | Valid loss: 0.2191 | Time: 0.0297
# Epoch 00096 | Train Acc: 0.9234 | Train Loss: 0.2166 | Valid Acc: 0.9234 | Valid loss: 0.2166 | Time: 0.0297
# Epoch 00097 | Train Acc: 0.9241 | Train Loss: 0.2141 | Valid Acc: 0.9241 | Valid loss: 0.2141 | Time: 0.0297
# Epoch 00098 | Train Acc: 0.9247 | Train Loss: 0.2119 | Valid Acc: 0.9247 | Valid loss: 0.2119 | Time: 0.0297
# Epoch 00099 | Train Acc: 0.9252 | Train Loss: 0.2097 | Valid Acc: 0.9252 | Valid loss: 0.2097 | Time: 0.0297
#
# Test Acc: 0.7447 | Test loss: 7.1200

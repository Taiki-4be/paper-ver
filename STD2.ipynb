# %%
from collections import defaultdict
import argparse
import torch as th
import torch.nn as nn
import torch.nn.functional as F
import dgl
import dgl.function as fn
import dgl.nn as dglnn
import tqdm
import pandas as pd
import numpy as np
import random as rd
import time
# Out:
# Using backend: pytorch

# %%
parser = argparse.ArgumentParser(description='RGCN')
parser.add_argument("--dropout", type=float, default=0,
        help="dropout probability")
parser.add_argument("--n-hidden", type=int, default=16,
        help="number of hidden units")
parser.add_argument("--gpu", type=int, default=-1,
        help="gpu")
parser.add_argument("--lr", type=float, default=1e-2,
        help="learning rate")
parser.add_argument("--n-bases", type=int, default=-1,
        help="number of filter weight matrices, default: -1 [use all]")
parser.add_argument("--n-layers", type=int, default=2,
        help="number of propagation rounds")
parser.add_argument("-e", "--n-epochs", type=int, default=50,
        help="number of training epochs")
parser.add_argument("--model_path", type=str, default=None,
        help='path for save the model')
parser.add_argument("--l2norm", type=float, default=0,
        help="l2 norm coef")
parser.add_argument("--use-self-loop", default=False, action='store_true',
        help="include self feature as a special relation")
fp = parser.add_mutually_exclusive_group(required=False)
fp.add_argument('--validation', dest='validation', action='store_true')
fp.add_argument('--testing', dest='validation', action='store_false')
parser.set_defaults(validation=True)

args = parser.parse_args(args=['-e','100','--n-layers','5','--testing','--gpu','0'])

# %% [markdown]
# ### CSVファイルからテンソルへの変換
# daskというライブラリを経由して、テンソルへと変換
# daskは大きなデータを扱う際にアシストしてくれるもの。学習の際に、サイズが大きいものをうまく扱う？
# ```
# import dask.dataframe as dd
# print("Loading CSV...")
# test = dd.read_csv("position-pass-position.csv", encoding = "UTF-8")
#
# print("Converting to Tensor...")
# test_tensor = th.tensor(test)
# ```

# %% [markdown]
# ### うまく行かなったのPandasで

# %% [markdown]
# ### グラフの構築
# 作ったテンソルをDGLに読み込ませるだけ

# %%
rel = pd.read_csv('data\STD2\data.csv')
id = pd.read_csv('data\STD2\list.csv')
pos_null = pd.read_csv('data\STD2\pn.csv')
null_pos = pd.read_csv('data\STD2\_np.csv')
t_link = pd.read_csv('data\STD2\link.csv')
mini = pd.read_csv('data\STD2\mini\list.csv')

# %%
graphdata = {
    ('position', 'pass','position'):(th.tensor(rel['fromid']),th.tensor(rel['toid'])),
    ('position','temporal','position'):(th.tensor(t_link['fromid']),th.tensor(t_link['toid'])),
    ('position','temporal','null'):(th.tensor(pos_null['fromid']),th.tensor(pos_null['nullid'])),
    ('null','temporal','position'):(th.tensor(null_pos['nullid']),th.tensor(null_pos['toid']))
}
g = dgl.heterograph(graphdata)

# %%
#label数２５
labels = th.tensor(id['posid'])
num_classes = 25 #len(g.ntypes)
"""
#label数４
labels = th.tensor(id['newpos'])
num_classes = 4 #len(g.ntypes)
"""
"""
#label数８
labels = th.tensor(id['8pos'])
num_classes = 8 #len(g.ntypes)
"""

# %%
category = 'position'
mask_wt = 0.7
final_num = len(mini)
num_node = g.num_nodes(category) - final_num

mask = [1] * int(num_node * mask_wt) + [0] * (num_node - int(num_node * mask_wt))
rd.shuffle(mask)
mask = mask + [0] * final_num

mask_wt = 0.2
mask_tr = [1] * int(final_num * mask_wt) + [0] * (final_num - int(final_num * mask_wt))
rd.shuffle(mask_tr)
mask_tr = [0] * (num_node - final_num) + mask_tr

train_mask = th.tensor(mask)
test_mask = th.tensor(mask_tr)
train_idx = th.nonzero(train_mask, as_tuple=False).squeeze()
test_idx = th.nonzero(test_mask, as_tuple=False).squeeze()
category_id = category
for i, ntype in enumerate(g.ntypes):
    if ntype == category:
        category_id = i

# %% [markdown]
# ### モデルの定義
# 今回はサンプルコードの中から`RelGraphConv`を引用する。使わないやつごと引用した

# %%
class RelGraphConvLayer(nn.Module):
    r"""Relational graph convolution layer.

    Parameters
    ----------
    in_feat : int
        Input feature size.
    out_feat : int
        Output feature size.
    rel_names : list[str]
        Relation names.
    num_bases : int, optional
        Number of bases. If is none, use number of relations. Default: None.
    weight : bool, optional
        True if a linear layer is applied after message passing. Default: True
    bias : bool, optional
        True if bias is added. Default: True
    activation : callable, optional
        Activation function. Default: None
    self_loop : bool, optional
        True to include self loop message. Default: False
    dropout : float, optional
        Dropout rate. Default: 0.0
    """
    def __init__(self,
                 in_feat,
                 out_feat,
                 rel_names,
                 num_bases,
                 *,
                 weight=True,
                 bias=True,
                 activation=None,
                 self_loop=False,
                 dropout=0.0):
        super(RelGraphConvLayer, self).__init__()
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.rel_names = rel_names
        self.num_bases = num_bases
        self.bias = bias
        self.activation = activation
        self.self_loop = self_loop

        self.conv = dglnn.HeteroGraphConv({
                rel : dglnn.GraphConv(in_feat, out_feat, norm='right', weight=False, bias=False)
                for rel in rel_names
            })

        self.use_weight = weight
        self.use_basis = num_bases < len(self.rel_names) and weight
        if self.use_weight:
            if self.use_basis:
                self.basis = dglnn.WeightBasis((in_feat, out_feat), num_bases, len(self.rel_names))
            else:
                self.weight = nn.Parameter(th.Tensor(len(self.rel_names), in_feat, out_feat))
                nn.init.xavier_uniform_(self.weight, gain=nn.init.calculate_gain('relu'))

        # bias
        if bias:
            self.h_bias = nn.Parameter(th.Tensor(out_feat))
            nn.init.zeros_(self.h_bias)

        # weight for self loop
        if self.self_loop:
            self.loop_weight = nn.Parameter(th.Tensor(in_feat, out_feat))
            nn.init.xavier_uniform_(self.loop_weight,
                                    gain=nn.init.calculate_gain('relu'))

        self.dropout = nn.Dropout(dropout)

    def forward(self, g, inputs):
        """Forward computation

        Parameters
        ----------
        g : DGLHeteroGraph
            Input graph.
        inputs : dict[str, torch.Tensor]
            Node feature for each node type.

        Returns
        -------
        dict[str, torch.Tensor]
            New node features for each node type.
        """
        g = g.local_var()
        if self.use_weight:
            weight = self.basis() if self.use_basis else self.weight
            wdict = {self.rel_names[i] : {'weight' : w.squeeze(0)}
                     for i, w in enumerate(th.split(weight, 1, dim=0))}
        else:
            wdict = {}

        if g.is_block:
            inputs_src = inputs
            inputs_dst = {k: v[:g.number_of_dst_nodes(k)] for k, v in inputs.items()}
        else:
            inputs_src = inputs_dst = inputs

        hs = self.conv(g, inputs, mod_kwargs=wdict)

        def _apply(ntype, h):
            if self.self_loop:
                h = h + th.matmul(inputs_dst[ntype], self.loop_weight)
            if self.bias:
                h = h + self.h_bias
            if self.activation:
                h = self.activation(h)
            return self.dropout(h)
        return {ntype : _apply(ntype, h) for ntype, h in hs.items()}

# %%
class RelGraphConvLayerHeteroAPI(nn.Module):
    r"""Relational graph convolution layer.

    Parameters
    ----------
    in_feat : int
        Input feature size.
    out_feat : int
        Output feature size.
    rel_names : list[str]
        Relation names.
    num_bases : int, optional
        Number of bases. If is none, use number of relations. Default: None.
    weight : bool, optional
        True if a linear layer is applied after message passing. Default: True
    bias : bool, optional
        True if bias is added. Default: True
    activation : callable, optional
        Activation function. Default: None
    self_loop : bool, optional
        True to include self loop message. Default: False
    dropout : float, optional
        Dropout rate. Default: 0.0
    """
    def __init__(self,
                 in_feat,
                 out_feat,
                 rel_names,
                 num_bases,
                 *,
                 weight=True,
                 bias=True,
                 activation=None,
                 self_loop=False,
                 dropout=0.0):
        super(RelGraphConvLayerHeteroAPI, self).__init__()
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.rel_names = rel_names
        self.num_bases = num_bases
        self.bias = bias
        self.activation = activation
        self.self_loop = self_loop

        self.use_weight = weight
        self.use_basis = num_bases < len(self.rel_names) and weight
        if self.use_weight:
            if self.use_basis:
                self.basis = dglnn.WeightBasis((in_feat, out_feat), num_bases, len(self.rel_names))
            else:
                self.weight = nn.Parameter(th.Tensor(len(self.rel_names), in_feat, out_feat))
                nn.init.xavier_uniform_(self.weight, gain=nn.init.calculate_gain('relu'))

        # bias
        if bias:
            self.h_bias = nn.Parameter(th.Tensor(out_feat))
            nn.init.zeros_(self.h_bias)

        # weight for self loop
        if self.self_loop:
            self.loop_weight = nn.Parameter(th.Tensor(in_feat, out_feat))
            nn.init.xavier_uniform_(self.loop_weight,
                                    gain=nn.init.calculate_gain('relu'))

        self.dropout = nn.Dropout(dropout)

    def forward(self, g, inputs):
        """Forward computation

        Parameters
        ----------
        g : DGLHeteroGraph
            Input graph.
        inputs : dict[str, torch.Tensor]
            Node feature for each node type.

        Returns
        -------
        dict[str, torch.Tensor]
            New node features for each node type.
        """
        g = g.local_var()
        if self.use_weight:
            weight = self.basis() if self.use_basis else self.weight
            wdict = {self.rel_names[i] : {'weight' : w.squeeze(0)}
                     for i, w in enumerate(th.split(weight, 1, dim=0))}
        else:
            wdict = {}

        inputs_src = inputs_dst = inputs

        for srctype,_,_ in g.canonical_etypes:
            g.nodes[srctype].data['h'] = inputs[srctype]

        if self.use_weight:
            g.apply_edges(fn.copy_u('h', 'm'))
            m = g.edata['m']
            for rel in g.canonical_etypes:
                _, etype, _ = rel
                g.edges[rel].data['h*w_r'] =  th.matmul(m[rel], wdict[etype]['weight'])
        else:
            g.apply_edges(fn.copy_u('h', 'h*w_r'))

        g.update_all(fn.copy_e('h*w_r', 'm'), fn.sum('m', 'h'))

        def _apply(ntype):
            h = g.nodes[ntype].data['h']
            if self.self_loop:
                h = h + th.matmul(inputs_dst[ntype], self.loop_weight)
            if self.bias:
                h = h + self.h_bias
            if self.activation:
                h = self.activation(h)
            return self.dropout(h)
        return {ntype : _apply(ntype) for ntype in g.dsttypes}

# %%
class RelGraphEmbed(nn.Module):
    r"""Embedding layer for featureless heterograph."""
    def __init__(self,
                 g,
                 embed_size,
                 embed_name='embed',
                 activation=None,
                 dropout=0.0):
        super(RelGraphEmbed, self).__init__()
        self.g = g
        self.embed_size = embed_size
        self.embed_name = embed_name
        self.activation = activation
        self.dropout = nn.Dropout(dropout)

        # create weight embeddings for each node for each relation
        self.embeds = nn.ParameterDict()
        for ntype in g.ntypes:
            embed = nn.Parameter(th.Tensor(g.number_of_nodes(ntype), self.embed_size))
            nn.init.xavier_uniform_(embed, gain=nn.init.calculate_gain('relu'))
            self.embeds[ntype] = embed

    def forward(self, block=None):
        """Forward computation

        Parameters
        ----------
        block : DGLHeteroGraph, optional
            If not specified, directly return the full graph with embeddings stored in
            :attr:`embed_name`. Otherwise, extract and store the embeddings to the block
            graph and return.

        Returns
        -------
        DGLHeteroGraph
            The block graph fed with embeddings.
        """
        return self.embeds

# %%
class EntityClassify(nn.Module):
    def __init__(self,
                 g,
                 h_dim, out_dim,
                 num_bases,
                 num_hidden_layers=1,
                 dropout=0,
                 use_self_loop=False):
        super(EntityClassify, self).__init__()
        self.g = g
        self.h_dim = h_dim
        self.out_dim = out_dim
        self.rel_names = list(set(g.etypes))
        self.rel_names.sort()
        if num_bases < 0 or num_bases > len(self.rel_names):
            self.num_bases = len(self.rel_names)
        else:
            self.num_bases = num_bases
        self.num_hidden_layers = num_hidden_layers
        self.dropout = dropout
        self.use_self_loop = use_self_loop

        self.embed_layer = RelGraphEmbed(g, self.h_dim)
        self.layers = nn.ModuleList()
        # i2h
        self.layers.append(RelGraphConvLayer(
            self.h_dim, self.h_dim, self.rel_names,
            self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
            dropout=self.dropout, weight=False))
        # h2h
        for i in range(self.num_hidden_layers):
            self.layers.append(RelGraphConvLayer(
                self.h_dim, self.h_dim, self.rel_names,
                self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
                dropout=self.dropout))
        # h2o
        self.layers.append(RelGraphConvLayer(
            self.h_dim, self.out_dim, self.rel_names,
            self.num_bases, activation=None,
            self_loop=self.use_self_loop))

    def forward(self, h=None, blocks=None):
        if h is None:
            # full graph training
            h = self.embed_layer()
        if blocks is None:
            # full graph training
            for layer in self.layers:
                h = layer(self.g, h)
        else:
            # minibatch training
            for layer, block in zip(self.layers, blocks):
                h = layer(block, h)
        return h

    def inference(self, g, batch_size, device, num_workers, x=None):
        """Minibatch inference of final representation over all node types.

        ***NOTE***
        For node classification, the model is trained to predict on only one node type's
        label.  Therefore, only that type's final representation is meaningful.
        """

        if x is None:
            x = self.embed_layer()

        for l, layer in enumerate(self.layers):
            y = {
                k: th.zeros(
                    g.number_of_nodes(k),
                    self.h_dim if l != len(self.layers) - 1 else self.out_dim)
                for k in g.ntypes}

            sampler = dgl.dataloading.MultiLayerFullNeighborSampler(1)
            dataloader = dgl.dataloading.NodeDataLoader(
                g,
                {k: th.arange(g.number_of_nodes(k)) for k in g.ntypes},
                sampler,
                batch_size=batch_size,
                shuffle=True,
                drop_last=False,
                num_workers=num_workers)

            for input_nodes, output_nodes, blocks in tqdm.tqdm(dataloader):
                block = blocks[0].to(device)

                h = {k: x[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
                h = layer(block, h)

                for k in h.keys():
                    y[k][output_nodes[k]] = h[k].cpu()

            x = y
        return y

# %%
class EntityClassify_HeteroAPI(nn.Module):
    def __init__(self,
                 g,
                 h_dim, out_dim,
                 num_bases,
                 num_hidden_layers=1,
                 dropout=0,
                 use_self_loop=False):
        super(EntityClassify_HeteroAPI, self).__init__()
        self.g = g
        self.h_dim = h_dim
        self.out_dim = out_dim
        self.rel_names = list(set(g.etypes))
        self.rel_names.sort()
        if num_bases < 0 or num_bases > len(self.rel_names):
            self.num_bases = len(self.rel_names)
        else:
            self.num_bases = num_bases
        self.num_hidden_layers = num_hidden_layers
        self.dropout = dropout
        self.use_self_loop = use_self_loop

        self.embed_layer = RelGraphEmbed(g, self.h_dim)
        self.layers = nn.ModuleList()
        # i2h
        self.layers.append(RelGraphConvLayerHeteroAPI(
            self.h_dim, self.h_dim, self.rel_names,
            self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
            dropout=self.dropout, weight=False))
        # h2h
        for i in range(self.num_hidden_layers):
            self.layers.append(RelGraphConvLayerHeteroAPI(
                self.h_dim, self.h_dim, self.rel_names,
                self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
                dropout=self.dropout))
        # h2o
        self.layers.append(RelGraphConvLayerHeteroAPI(
            self.h_dim, self.out_dim, self.rel_names,
            self.num_bases, activation=None,
            self_loop=self.use_self_loop))

    def forward(self, h=None, blocks=None):
        if h is None:
            # full graph training
            h = self.embed_layer()
        if blocks is None:
            # full graph training
            for layer in self.layers:
                h = layer(self.g, h)
        else:
            # minibatch training
            for layer, block in zip(self.layers, blocks):
                h = layer(block, h)
        return h

    def inference(self, g, batch_size, device, num_workers, x=None):
        """Minibatch inference of final representation over all node types.

        ***NOTE***
        For node classification, the model is trained to predict on only one node type's
        label.  Therefore, only that type's final representation is meaningful.
        """

        if x is None:
            x = self.embed_layer()

        for l, layer in enumerate(self.layers):
            y = {
                k: th.zeros(
                    g.number_of_nodes(k),
                    self.h_dim if l != len(self.layers) - 1 else self.out_dim)
                for k in g.ntypes}

            sampler = dgl.dataloading.MultiLayerFullNeighborSampler(1)
            dataloader = dgl.dataloading.NodeDataLoader(
                g,
                {k: th.arange(g.number_of_nodes(k)) for k in g.ntypes},
                sampler,
                batch_size=batch_size,
                shuffle=True,
                drop_last=False,
                num_workers=num_workers)

            for input_nodes, output_nodes, blocks in tqdm.tqdm(dataloader):
                block = blocks[0].to(device)

                h = {k: x[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
                h = layer(block, h)

                for k in h.keys():
                    y[k][output_nodes[k]] = h[k].cpu()

            x = y
        return y

# %% [markdown]
# ### ノード分類の実装
# ここから作ったグラフを使って学習を行う。

# %%
# split dataset into train, validate, test
if args.validation:
    val_idx = train_idx[:len(train_idx) // 5]
    train_idx = train_idx[len(train_idx) // 5:]
else:
    val_idx = train_idx

# %%
# check cuda
use_cuda = args.gpu >= 0 and th.cuda.is_available()
if use_cuda:
    th.cuda.set_device(args.gpu)
    g = g.to('cuda:%d' % args.gpu)
    labels = labels.cuda()
    train_idx = train_idx.cuda()
    test_idx = test_idx.cuda()

# %%
# create model
model = EntityClassify(g,
                       args.n_hidden,
                       num_classes,
                       num_bases=args.n_bases,
                       num_hidden_layers=args.n_layers - 2,
                       dropout=args.dropout,
                       use_self_loop=args.use_self_loop)

# %%
if use_cuda:
        model.cuda()

# %%
# optimizer
optimizer = th.optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.l2norm)

# %%
# training loop
print("start training...")
dur = []
model.train()
for epoch in range(args.n_epochs):
    optimizer.zero_grad()
    if epoch > 5:
        t0 = time.time()
    logits = model()[category]
    loss = F.cross_entropy(logits[train_idx], labels[train_idx])
    loss.backward()
    optimizer.step()
    t1 = time.time()

    if epoch > 5:
        dur.append(t1 - t0)
    train_acc = th.sum(logits[train_idx].argmax(dim=1) == labels[train_idx]).item() / len(train_idx)
    val_loss = F.cross_entropy(logits[val_idx], labels[val_idx])
    val_acc = th.sum(logits[val_idx].argmax(dim=1) == labels[val_idx]).item() / len(val_idx)
    print("Epoch {:05d} | Train Acc: {:.4f} | Train Loss: {:.4f} | Valid Acc: {:.4f} | Valid loss: {:.4f} | Time: {:.4f}".
         format(epoch, train_acc, loss.item(), val_acc, val_loss.item(), np.average(dur)))
print()
if args.model_path is not None:
    th.save(model.state_dict(), args.model_path)

model.eval()
logits = model.forward()[category]
test_loss = F.cross_entropy(logits[test_idx], labels[test_idx])
test_acc = th.sum(logits[test_idx].argmax(dim=1) == labels[test_idx]).item() / len(test_idx)
print("Test Acc: {:.4f} | Test loss: {:.4f}".format(test_acc, test_loss.item()))
print()
# Out:
# start training...
# Epoch 00000 | Train Acc: 0.0740 | Train Loss: 2.0796 | Valid Acc: 0.0740 | Valid loss: 2.0796 | Time: nan
# Epoch 00001 | Train Acc: 0.2065 | Train Loss: 2.0755 | Valid Acc: 0.2065 | Valid loss: 2.0755 | Time: nan
# Epoch 00002 | Train Acc: 0.2065 | Train Loss: 2.0711 | Valid Acc: 0.2065 | Valid loss: 2.0711 | Time: nan
# Epoch 00003 | Train Acc: 0.2065 | Train Loss: 2.0657 | Valid Acc: 0.2065 | Valid loss: 2.0657 | Time: nan
# Epoch 00004 | Train Acc: 0.2151 | Train Loss: 2.0593 | Valid Acc: 0.2151 | Valid loss: 2.0593 | Time: nan
# Epoch 00005 | Train Acc: 0.2190 | Train Loss: 2.0510 | Valid Acc: 0.2190 | Valid loss: 2.0510 | Time: nan
# Epoch 00006 | Train Acc: 0.2169 | Train Loss: 2.0400 | Valid Acc: 0.2169 | Valid loss: 2.0400 | Time: 0.0312
# Epoch 00007 | Train Acc: 0.2159 | Train Loss: 2.0259 | Valid Acc: 0.2159 | Valid loss: 2.0259 | Time: 0.0316
# Epoch 00008 | Train Acc: 0.2147 | Train Loss: 2.0091 | Valid Acc: 0.2147 | Valid loss: 2.0091 | Time: 0.0324
# Epoch 00009 | Train Acc: 0.2147 | Train Loss: 1.9929 | Valid Acc: 0.2147 | Valid loss: 1.9929 | Time: 0.0315
# Epoch 00010 | Train Acc: 0.2145 | Train Loss: 1.9871 | Valid Acc: 0.2145 | Valid loss: 1.9871 | Time: 0.0312
# Epoch 00011 | Train Acc: 0.2155 | Train Loss: 1.9910 | Valid Acc: 0.2155 | Valid loss: 1.9910 | Time: 0.0310
# Epoch 00012 | Train Acc: 0.2309 | Train Loss: 1.9843 | Valid Acc: 0.2309 | Valid loss: 1.9843 | Time: 0.0310
# Epoch 00013 | Train Acc: 0.2243 | Train Loss: 1.9733 | Valid Acc: 0.2243 | Valid loss: 1.9733 | Time: 0.0309
# Epoch 00014 | Train Acc: 0.2186 | Train Loss: 1.9659 | Valid Acc: 0.2186 | Valid loss: 1.9659 | Time: 0.0310
# Epoch 00015 | Train Acc: 0.2208 | Train Loss: 1.9625 | Valid Acc: 0.2208 | Valid loss: 1.9625 | Time: 0.0310
# Epoch 00016 | Train Acc: 0.2217 | Train Loss: 1.9601 | Valid Acc: 0.2217 | Valid loss: 1.9601 | Time: 0.0307
# Epoch 00017 | Train Acc: 0.2227 | Train Loss: 1.9566 | Valid Acc: 0.2227 | Valid loss: 1.9566 | Time: 0.0306
# Epoch 00018 | Train Acc: 0.2250 | Train Loss: 1.9510 | Valid Acc: 0.2250 | Valid loss: 1.9510 | Time: 0.0305
# Epoch 00019 | Train Acc: 0.2287 | Train Loss: 1.9433 | Valid Acc: 0.2287 | Valid loss: 1.9433 | Time: 0.0305
# Epoch 00020 | Train Acc: 0.2315 | Train Loss: 1.9344 | Valid Acc: 0.2315 | Valid loss: 1.9344 | Time: 0.0305
# Epoch 00021 | Train Acc: 0.2354 | Train Loss: 1.9255 | Valid Acc: 0.2354 | Valid loss: 1.9255 | Time: 0.0306
# Epoch 00022 | Train Acc: 0.2359 | Train Loss: 1.9173 | Valid Acc: 0.2359 | Valid loss: 1.9173 | Time: 0.0306
# Epoch 00023 | Train Acc: 0.2379 | Train Loss: 1.9084 | Valid Acc: 0.2379 | Valid loss: 1.9084 | Time: 0.0305
# Epoch 00024 | Train Acc: 0.2449 | Train Loss: 1.8971 | Valid Acc: 0.2449 | Valid loss: 1.8971 | Time: 0.0305
# Epoch 00025 | Train Acc: 0.2486 | Train Loss: 1.8833 | Valid Acc: 0.2486 | Valid loss: 1.8833 | Time: 0.0304
# Epoch 00026 | Train Acc: 0.2564 | Train Loss: 1.8679 | Valid Acc: 0.2564 | Valid loss: 1.8679 | Time: 0.0305
# Epoch 00027 | Train Acc: 0.2644 | Train Loss: 1.8516 | Valid Acc: 0.2644 | Valid loss: 1.8516 | Time: 0.0305
# Epoch 00028 | Train Acc: 0.2733 | Train Loss: 1.8340 | Valid Acc: 0.2733 | Valid loss: 1.8340 | Time: 0.0305
# Epoch 00029 | Train Acc: 0.2788 | Train Loss: 1.8147 | Valid Acc: 0.2788 | Valid loss: 1.8147 | Time: 0.0305
# Epoch 00030 | Train Acc: 0.2838 | Train Loss: 1.7940 | Valid Acc: 0.2838 | Valid loss: 1.7940 | Time: 0.0305
# Epoch 00031 | Train Acc: 0.2938 | Train Loss: 1.7719 | Valid Acc: 0.2938 | Valid loss: 1.7719 | Time: 0.0305
# Epoch 00032 | Train Acc: 0.3064 | Train Loss: 1.7488 | Valid Acc: 0.3064 | Valid loss: 1.7488 | Time: 0.0304
# Epoch 00033 | Train Acc: 0.3198 | Train Loss: 1.7248 | Valid Acc: 0.3198 | Valid loss: 1.7248 | Time: 0.0305
# Epoch 00034 | Train Acc: 0.3327 | Train Loss: 1.6999 | Valid Acc: 0.3327 | Valid loss: 1.6999 | Time: 0.0304
# Epoch 00035 | Train Acc: 0.3405 | Train Loss: 1.6737 | Valid Acc: 0.3405 | Valid loss: 1.6737 | Time: 0.0304
# Epoch 00036 | Train Acc: 0.3533 | Train Loss: 1.6459 | Valid Acc: 0.3533 | Valid loss: 1.6459 | Time: 0.0304
# Epoch 00037 | Train Acc: 0.3718 | Train Loss: 1.6168 | Valid Acc: 0.3718 | Valid loss: 1.6168 | Time: 0.0304
# Epoch 00038 | Train Acc: 0.3868 | Train Loss: 1.5857 | Valid Acc: 0.3868 | Valid loss: 1.5857 | Time: 0.0303
# Epoch 00039 | Train Acc: 0.4035 | Train Loss: 1.5529 | Valid Acc: 0.4035 | Valid loss: 1.5529 | Time: 0.0303
# Epoch 00040 | Train Acc: 0.4201 | Train Loss: 1.5185 | Valid Acc: 0.4201 | Valid loss: 1.5185 | Time: 0.0304
# Epoch 00041 | Train Acc: 0.4318 | Train Loss: 1.4831 | Valid Acc: 0.4318 | Valid loss: 1.4831 | Time: 0.0303
# Epoch 00042 | Train Acc: 0.4438 | Train Loss: 1.4469 | Valid Acc: 0.4438 | Valid loss: 1.4469 | Time: 0.0303
# Epoch 00043 | Train Acc: 0.4577 | Train Loss: 1.4096 | Valid Acc: 0.4577 | Valid loss: 1.4096 | Time: 0.0304
# Epoch 00044 | Train Acc: 0.4754 | Train Loss: 1.3714 | Valid Acc: 0.4754 | Valid loss: 1.3714 | Time: 0.0304
# Epoch 00045 | Train Acc: 0.4888 | Train Loss: 1.3334 | Valid Acc: 0.4888 | Valid loss: 1.3334 | Time: 0.0304
# Epoch 00046 | Train Acc: 0.5042 | Train Loss: 1.3000 | Valid Acc: 0.5042 | Valid loss: 1.3000 | Time: 0.0304
# Epoch 00047 | Train Acc: 0.4931 | Train Loss: 1.3004 | Valid Acc: 0.4931 | Valid loss: 1.3004 | Time: 0.0304
# Epoch 00048 | Train Acc: 0.5244 | Train Loss: 1.2457 | Valid Acc: 0.5244 | Valid loss: 1.2457 | Time: 0.0303
# Epoch 00049 | Train Acc: 0.5369 | Train Loss: 1.2192 | Valid Acc: 0.5369 | Valid loss: 1.2192 | Time: 0.0303
# Epoch 00050 | Train Acc: 0.5560 | Train Loss: 1.1776 | Valid Acc: 0.5560 | Valid loss: 1.1776 | Time: 0.0303
# Epoch 00051 | Train Acc: 0.5546 | Train Loss: 1.1607 | Valid Acc: 0.5546 | Valid loss: 1.1607 | Time: 0.0302
# Epoch 00052 | Train Acc: 0.5826 | Train Loss: 1.1156 | Valid Acc: 0.5826 | Valid loss: 1.1156 | Time: 0.0302
# Epoch 00053 | Train Acc: 0.5844 | Train Loss: 1.1012 | Valid Acc: 0.5844 | Valid loss: 1.1012 | Time: 0.0302
# Epoch 00054 | Train Acc: 0.6136 | Train Loss: 1.0595 | Valid Acc: 0.6136 | Valid loss: 1.0595 | Time: 0.0302
# Epoch 00055 | Train Acc: 0.6134 | Train Loss: 1.0409 | Valid Acc: 0.6134 | Valid loss: 1.0409 | Time: 0.0302
# Epoch 00056 | Train Acc: 0.6259 | Train Loss: 1.0068 | Valid Acc: 0.6259 | Valid loss: 1.0068 | Time: 0.0302
# Epoch 00057 | Train Acc: 0.6350 | Train Loss: 0.9833 | Valid Acc: 0.6350 | Valid loss: 0.9833 | Time: 0.0302
# Epoch 00058 | Train Acc: 0.6541 | Train Loss: 0.9559 | Valid Acc: 0.6541 | Valid loss: 0.9559 | Time: 0.0302
# Epoch 00059 | Train Acc: 0.6621 | Train Loss: 0.9281 | Valid Acc: 0.6621 | Valid loss: 0.9281 | Time: 0.0303
# Epoch 00060 | Train Acc: 0.6700 | Train Loss: 0.9051 | Valid Acc: 0.6700 | Valid loss: 0.9051 | Time: 0.0303
# Epoch 00061 | Train Acc: 0.6821 | Train Loss: 0.8760 | Valid Acc: 0.6821 | Valid loss: 0.8760 | Time: 0.0302
# Epoch 00062 | Train Acc: 0.6930 | Train Loss: 0.8565 | Valid Acc: 0.6930 | Valid loss: 0.8565 | Time: 0.0302
# Epoch 00063 | Train Acc: 0.7031 | Train Loss: 0.8252 | Valid Acc: 0.7031 | Valid loss: 0.8252 | Time: 0.0303
# Epoch 00064 | Train Acc: 0.7078 | Train Loss: 0.8070 | Valid Acc: 0.7078 | Valid loss: 0.8070 | Time: 0.0303
# Epoch 00065 | Train Acc: 0.7212 | Train Loss: 0.7796 | Valid Acc: 0.7212 | Valid loss: 0.7796 | Time: 0.0303
# Epoch 00066 | Train Acc: 0.7345 | Train Loss: 0.7588 | Valid Acc: 0.7345 | Valid loss: 0.7588 | Time: 0.0303
# Epoch 00067 | Train Acc: 0.7407 | Train Loss: 0.7347 | Valid Acc: 0.7407 | Valid loss: 0.7347 | Time: 0.0303
# Epoch 00068 | Train Acc: 0.7467 | Train Loss: 0.7166 | Valid Acc: 0.7467 | Valid loss: 0.7166 | Time: 0.0303
# Epoch 00069 | Train Acc: 0.7606 | Train Loss: 0.6917 | Valid Acc: 0.7606 | Valid loss: 0.6917 | Time: 0.0303
# Epoch 00070 | Train Acc: 0.7662 | Train Loss: 0.6731 | Valid Acc: 0.7662 | Valid loss: 0.6731 | Time: 0.0303
# Epoch 00071 | Train Acc: 0.7759 | Train Loss: 0.6506 | Valid Acc: 0.7759 | Valid loss: 0.6506 | Time: 0.0303
# Epoch 00072 | Train Acc: 0.7800 | Train Loss: 0.6350 | Valid Acc: 0.7800 | Valid loss: 0.6350 | Time: 0.0303
# Epoch 00073 | Train Acc: 0.7874 | Train Loss: 0.6150 | Valid Acc: 0.7874 | Valid loss: 0.6150 | Time: 0.0303
# Epoch 00074 | Train Acc: 0.7935 | Train Loss: 0.5991 | Valid Acc: 0.7935 | Valid loss: 0.5991 | Time: 0.0303
# Epoch 00075 | Train Acc: 0.7962 | Train Loss: 0.5823 | Valid Acc: 0.7962 | Valid loss: 0.5823 | Time: 0.0303
# Epoch 00076 | Train Acc: 0.8059 | Train Loss: 0.5651 | Valid Acc: 0.8059 | Valid loss: 0.5651 | Time: 0.0303
# Epoch 00077 | Train Acc: 0.8096 | Train Loss: 0.5499 | Valid Acc: 0.8096 | Valid loss: 0.5499 | Time: 0.0302
# Epoch 00078 | Train Acc: 0.8178 | Train Loss: 0.5315 | Valid Acc: 0.8178 | Valid loss: 0.5315 | Time: 0.0302
# Epoch 00079 | Train Acc: 0.8221 | Train Loss: 0.5169 | Valid Acc: 0.8221 | Valid loss: 0.5169 | Time: 0.0302
# Epoch 00080 | Train Acc: 0.8266 | Train Loss: 0.5024 | Valid Acc: 0.8266 | Valid loss: 0.5024 | Time: 0.0302
# Epoch 00081 | Train Acc: 0.8318 | Train Loss: 0.4887 | Valid Acc: 0.8318 | Valid loss: 0.4887 | Time: 0.0302
# Epoch 00082 | Train Acc: 0.8357 | Train Loss: 0.4777 | Valid Acc: 0.8357 | Valid loss: 0.4777 | Time: 0.0302
# Epoch 00083 | Train Acc: 0.8386 | Train Loss: 0.4658 | Valid Acc: 0.8386 | Valid loss: 0.4658 | Time: 0.0302
# Epoch 00084 | Train Acc: 0.8429 | Train Loss: 0.4581 | Valid Acc: 0.8429 | Valid loss: 0.4581 | Time: 0.0302
# Epoch 00085 | Train Acc: 0.8445 | Train Loss: 0.4513 | Valid Acc: 0.8445 | Valid loss: 0.4513 | Time: 0.0302
# Epoch 00086 | Train Acc: 0.8480 | Train Loss: 0.4430 | Valid Acc: 0.8480 | Valid loss: 0.4430 | Time: 0.0302
# Epoch 00087 | Train Acc: 0.8509 | Train Loss: 0.4282 | Valid Acc: 0.8509 | Valid loss: 0.4282 | Time: 0.0302
# Epoch 00088 | Train Acc: 0.8569 | Train Loss: 0.4118 | Valid Acc: 0.8569 | Valid loss: 0.4118 | Time: 0.0302
# Epoch 00089 | Train Acc: 0.8610 | Train Loss: 0.4065 | Valid Acc: 0.8610 | Valid loss: 0.4065 | Time: 0.0302
# Epoch 00090 | Train Acc: 0.8610 | Train Loss: 0.4008 | Valid Acc: 0.8610 | Valid loss: 0.4008 | Time: 0.0302
# Epoch 00091 | Train Acc: 0.8676 | Train Loss: 0.3869 | Valid Acc: 0.8676 | Valid loss: 0.3869 | Time: 0.0302
# Epoch 00092 | Train Acc: 0.8688 | Train Loss: 0.3794 | Valid Acc: 0.8688 | Valid loss: 0.3794 | Time: 0.0302
# Epoch 00093 | Train Acc: 0.8713 | Train Loss: 0.3738 | Valid Acc: 0.8713 | Valid loss: 0.3738 | Time: 0.0302
# Epoch 00094 | Train Acc: 0.8756 | Train Loss: 0.3653 | Valid Acc: 0.8756 | Valid loss: 0.3653 | Time: 0.0303
# Epoch 00095 | Train Acc: 0.8754 | Train Loss: 0.3561 | Valid Acc: 0.8754 | Valid loss: 0.3561 | Time: 0.0303
# Epoch 00096 | Train Acc: 0.8766 | Train Loss: 0.3520 | Valid Acc: 0.8766 | Valid loss: 0.3520 | Time: 0.0303
# Epoch 00097 | Train Acc: 0.8820 | Train Loss: 0.3447 | Valid Acc: 0.8820 | Valid loss: 0.3447 | Time: 0.0303
# Epoch 00098 | Train Acc: 0.8840 | Train Loss: 0.3370 | Valid Acc: 0.8840 | Valid loss: 0.3370 | Time: 0.0303
# Epoch 00099 | Train Acc: 0.8832 | Train Loss: 0.3325 | Valid Acc: 0.8832 | Valid loss: 0.3325 | Time: 0.0303
#
# Test Acc: 0.7273 | Test loss: 1.5059

# %%
from collections import defaultdict
import argparse
import torch as th
import torch.nn as nn
import torch.nn.functional as F
import dgl
import dgl.function as fn
import dgl.nn as dglnn
import tqdm
import pandas as pd
import numpy as np
import random as rd
import time

# %%
parser = argparse.ArgumentParser(description='RGCN')
parser.add_argument("--dropout", type=float, default=0,
        help="dropout probability")
parser.add_argument("--n-hidden", type=int, default=16,
        help="number of hidden units")
parser.add_argument("--gpu", type=int, default=-1,
        help="gpu")
parser.add_argument("--lr", type=float, default=1e-2,
        help="learning rate")
parser.add_argument("--n-bases", type=int, default=-1,
        help="number of filter weight matrices, default: -1 [use all]")
parser.add_argument("--n-layers", type=int, default=2,
        help="number of propagation rounds")
parser.add_argument("-e", "--n-epochs", type=int, default=50,
        help="number of training epochs")
parser.add_argument("--model_path", type=str, default=None,
        help='path for save the model')
parser.add_argument("--l2norm", type=float, default=0,
        help="l2 norm coef")
parser.add_argument("--use-self-loop", default=False, action='store_true',
        help="include self feature as a special relation")
fp = parser.add_mutually_exclusive_group(required=False)
fp.add_argument('--validation', dest='validation', action='store_true')
fp.add_argument('--testing', dest='validation', action='store_false')
parser.set_defaults(validation=True)

args = parser.parse_args(args=['-e','100','--n-layers','5','--testing','--gpu','0'])

# %% [markdown]
# ### CSVファイルからテンソルへの変換
# daskというライブラリを経由して、テンソルへと変換
# daskは大きなデータを扱う際にアシストしてくれるもの。学習の際に、サイズが大きいものをうまく扱う？
# ```
# import dask.dataframe as dd
# print("Loading CSV...")
# test = dd.read_csv("position-pass-position.csv", encoding = "UTF-8")
#
# print("Converting to Tensor...")
# test_tensor = th.tensor(test)
# ```

# %% [markdown]
# ### うまく行かなったのPandasで

# %% [markdown]
# ### グラフの構築
# 作ったテンソルをDGLに読み込ませるだけ

# %%
rel = pd.read_csv('data\STD4\data.csv')
id = pd.read_csv('data\STD4\list.csv')
pos_null = pd.read_csv('data\STD4\pn.csv')
null_pos = pd.read_csv('data\STD4\_np.csv')
t_link = pd.read_csv('data\STD4\link.csv')
mini = pd.read_csv('data\STD4\mini\list.csv')

# %%
graphdata = {
    ('position', 'pass','position'):(th.tensor(rel['fromid']),th.tensor(rel['toid'])),
    ('position','temporal','position'):(th.tensor(t_link['fromid']),th.tensor(t_link['toid'])),
    ('position','temporal','null'):(th.tensor(pos_null['fromid']),th.tensor(pos_null['nullid'])),
    ('null','temporal','position'):(th.tensor(null_pos['nullid']),th.tensor(null_pos['toid']))
}
g = dgl.heterograph(graphdata)

# %%
#label数２５
labels = th.tensor(id['posid'])
num_classes = 25 #len(g.ntypes)
"""
#label数４
labels = th.tensor(id['newpos'])
num_classes = 4 #len(g.ntypes)
"""
"""
#label数８
labels = th.tensor(id['8pos'])
num_classes = 8 #len(g.ntypes)
"""

# %%
category = 'position'
mask_wt = 0.7
final_num = len(mini)
num_node = g.num_nodes(category) - final_num

mask = [1] * int(num_node * mask_wt) + [0] * (num_node - int(num_node * mask_wt))
rd.shuffle(mask)
mask = mask + [0] * final_num

mask_wt = 0.2
mask_tr = [1] * int(final_num * mask_wt) + [0] * (final_num - int(final_num * mask_wt))
rd.shuffle(mask_tr)
mask_tr = [0] * (num_node - final_num) + mask_tr

train_mask = th.tensor(mask)
test_mask = th.tensor(mask_tr)
train_idx = th.nonzero(train_mask, as_tuple=False).squeeze()
test_idx = th.nonzero(test_mask, as_tuple=False).squeeze()
category_id = category
for i, ntype in enumerate(g.ntypes):
    if ntype == category:
        category_id = i

# %% [markdown]
# ### モデルの定義
# 今回はサンプルコードの中から`RelGraphConv`を引用する。使わないやつごと引用した

# %%
class RelGraphConvLayer(nn.Module):
    r"""Relational graph convolution layer.

    Parameters
    ----------
    in_feat : int
        Input feature size.
    out_feat : int
        Output feature size.
    rel_names : list[str]
        Relation names.
    num_bases : int, optional
        Number of bases. If is none, use number of relations. Default: None.
    weight : bool, optional
        True if a linear layer is applied after message passing. Default: True
    bias : bool, optional
        True if bias is added. Default: True
    activation : callable, optional
        Activation function. Default: None
    self_loop : bool, optional
        True to include self loop message. Default: False
    dropout : float, optional
        Dropout rate. Default: 0.0
    """
    def __init__(self,
                 in_feat,
                 out_feat,
                 rel_names,
                 num_bases,
                 *,
                 weight=True,
                 bias=True,
                 activation=None,
                 self_loop=False,
                 dropout=0.0):
        super(RelGraphConvLayer, self).__init__()
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.rel_names = rel_names
        self.num_bases = num_bases
        self.bias = bias
        self.activation = activation
        self.self_loop = self_loop

        self.conv = dglnn.HeteroGraphConv({
                rel : dglnn.GraphConv(in_feat, out_feat, norm='right', weight=False, bias=False)
                for rel in rel_names
            })

        self.use_weight = weight
        self.use_basis = num_bases < len(self.rel_names) and weight
        if self.use_weight:
            if self.use_basis:
                self.basis = dglnn.WeightBasis((in_feat, out_feat), num_bases, len(self.rel_names))
            else:
                self.weight = nn.Parameter(th.Tensor(len(self.rel_names), in_feat, out_feat))
                nn.init.xavier_uniform_(self.weight, gain=nn.init.calculate_gain('relu'))

        # bias
        if bias:
            self.h_bias = nn.Parameter(th.Tensor(out_feat))
            nn.init.zeros_(self.h_bias)

        # weight for self loop
        if self.self_loop:
            self.loop_weight = nn.Parameter(th.Tensor(in_feat, out_feat))
            nn.init.xavier_uniform_(self.loop_weight,
                                    gain=nn.init.calculate_gain('relu'))

        self.dropout = nn.Dropout(dropout)

    def forward(self, g, inputs):
        """Forward computation

        Parameters
        ----------
        g : DGLHeteroGraph
            Input graph.
        inputs : dict[str, torch.Tensor]
            Node feature for each node type.

        Returns
        -------
        dict[str, torch.Tensor]
            New node features for each node type.
        """
        g = g.local_var()
        if self.use_weight:
            weight = self.basis() if self.use_basis else self.weight
            wdict = {self.rel_names[i] : {'weight' : w.squeeze(0)}
                     for i, w in enumerate(th.split(weight, 1, dim=0))}
        else:
            wdict = {}

        if g.is_block:
            inputs_src = inputs
            inputs_dst = {k: v[:g.number_of_dst_nodes(k)] for k, v in inputs.items()}
        else:
            inputs_src = inputs_dst = inputs

        hs = self.conv(g, inputs, mod_kwargs=wdict)

        def _apply(ntype, h):
            if self.self_loop:
                h = h + th.matmul(inputs_dst[ntype], self.loop_weight)
            if self.bias:
                h = h + self.h_bias
            if self.activation:
                h = self.activation(h)
            return self.dropout(h)
        return {ntype : _apply(ntype, h) for ntype, h in hs.items()}

# %%
class RelGraphConvLayerHeteroAPI(nn.Module):
    r"""Relational graph convolution layer.

    Parameters
    ----------
    in_feat : int
        Input feature size.
    out_feat : int
        Output feature size.
    rel_names : list[str]
        Relation names.
    num_bases : int, optional
        Number of bases. If is none, use number of relations. Default: None.
    weight : bool, optional
        True if a linear layer is applied after message passing. Default: True
    bias : bool, optional
        True if bias is added. Default: True
    activation : callable, optional
        Activation function. Default: None
    self_loop : bool, optional
        True to include self loop message. Default: False
    dropout : float, optional
        Dropout rate. Default: 0.0
    """
    def __init__(self,
                 in_feat,
                 out_feat,
                 rel_names,
                 num_bases,
                 *,
                 weight=True,
                 bias=True,
                 activation=None,
                 self_loop=False,
                 dropout=0.0):
        super(RelGraphConvLayerHeteroAPI, self).__init__()
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.rel_names = rel_names
        self.num_bases = num_bases
        self.bias = bias
        self.activation = activation
        self.self_loop = self_loop

        self.use_weight = weight
        self.use_basis = num_bases < len(self.rel_names) and weight
        if self.use_weight:
            if self.use_basis:
                self.basis = dglnn.WeightBasis((in_feat, out_feat), num_bases, len(self.rel_names))
            else:
                self.weight = nn.Parameter(th.Tensor(len(self.rel_names), in_feat, out_feat))
                nn.init.xavier_uniform_(self.weight, gain=nn.init.calculate_gain('relu'))

        # bias
        if bias:
            self.h_bias = nn.Parameter(th.Tensor(out_feat))
            nn.init.zeros_(self.h_bias)

        # weight for self loop
        if self.self_loop:
            self.loop_weight = nn.Parameter(th.Tensor(in_feat, out_feat))
            nn.init.xavier_uniform_(self.loop_weight,
                                    gain=nn.init.calculate_gain('relu'))

        self.dropout = nn.Dropout(dropout)

    def forward(self, g, inputs):
        """Forward computation

        Parameters
        ----------
        g : DGLHeteroGraph
            Input graph.
        inputs : dict[str, torch.Tensor]
            Node feature for each node type.

        Returns
        -------
        dict[str, torch.Tensor]
            New node features for each node type.
        """
        g = g.local_var()
        if self.use_weight:
            weight = self.basis() if self.use_basis else self.weight
            wdict = {self.rel_names[i] : {'weight' : w.squeeze(0)}
                     for i, w in enumerate(th.split(weight, 1, dim=0))}
        else:
            wdict = {}

        inputs_src = inputs_dst = inputs

        for srctype,_,_ in g.canonical_etypes:
            g.nodes[srctype].data['h'] = inputs[srctype]

        if self.use_weight:
            g.apply_edges(fn.copy_u('h', 'm'))
            m = g.edata['m']
            for rel in g.canonical_etypes:
                _, etype, _ = rel
                g.edges[rel].data['h*w_r'] =  th.matmul(m[rel], wdict[etype]['weight'])
        else:
            g.apply_edges(fn.copy_u('h', 'h*w_r'))

        g.update_all(fn.copy_e('h*w_r', 'm'), fn.sum('m', 'h'))

        def _apply(ntype):
            h = g.nodes[ntype].data['h']
            if self.self_loop:
                h = h + th.matmul(inputs_dst[ntype], self.loop_weight)
            if self.bias:
                h = h + self.h_bias
            if self.activation:
                h = self.activation(h)
            return self.dropout(h)
        return {ntype : _apply(ntype) for ntype in g.dsttypes}

# %%
class RelGraphEmbed(nn.Module):
    r"""Embedding layer for featureless heterograph."""
    def __init__(self,
                 g,
                 embed_size,
                 embed_name='embed',
                 activation=None,
                 dropout=0.0):
        super(RelGraphEmbed, self).__init__()
        self.g = g
        self.embed_size = embed_size
        self.embed_name = embed_name
        self.activation = activation
        self.dropout = nn.Dropout(dropout)

        # create weight embeddings for each node for each relation
        self.embeds = nn.ParameterDict()
        for ntype in g.ntypes:
            embed = nn.Parameter(th.Tensor(g.number_of_nodes(ntype), self.embed_size))
            nn.init.xavier_uniform_(embed, gain=nn.init.calculate_gain('relu'))
            self.embeds[ntype] = embed

    def forward(self, block=None):
        """Forward computation

        Parameters
        ----------
        block : DGLHeteroGraph, optional
            If not specified, directly return the full graph with embeddings stored in
            :attr:`embed_name`. Otherwise, extract and store the embeddings to the block
            graph and return.

        Returns
        -------
        DGLHeteroGraph
            The block graph fed with embeddings.
        """
        return self.embeds

# %%
class EntityClassify(nn.Module):
    def __init__(self,
                 g,
                 h_dim, out_dim,
                 num_bases,
                 num_hidden_layers=1,
                 dropout=0,
                 use_self_loop=False):
        super(EntityClassify, self).__init__()
        self.g = g
        self.h_dim = h_dim
        self.out_dim = out_dim
        self.rel_names = list(set(g.etypes))
        self.rel_names.sort()
        if num_bases < 0 or num_bases > len(self.rel_names):
            self.num_bases = len(self.rel_names)
        else:
            self.num_bases = num_bases
        self.num_hidden_layers = num_hidden_layers
        self.dropout = dropout
        self.use_self_loop = use_self_loop

        self.embed_layer = RelGraphEmbed(g, self.h_dim)
        self.layers = nn.ModuleList()
        # i2h
        self.layers.append(RelGraphConvLayer(
            self.h_dim, self.h_dim, self.rel_names,
            self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
            dropout=self.dropout, weight=False))
        # h2h
        for i in range(self.num_hidden_layers):
            self.layers.append(RelGraphConvLayer(
                self.h_dim, self.h_dim, self.rel_names,
                self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
                dropout=self.dropout))
        # h2o
        self.layers.append(RelGraphConvLayer(
            self.h_dim, self.out_dim, self.rel_names,
            self.num_bases, activation=None,
            self_loop=self.use_self_loop))

    def forward(self, h=None, blocks=None):
        if h is None:
            # full graph training
            h = self.embed_layer()
        if blocks is None:
            # full graph training
            for layer in self.layers:
                h = layer(self.g, h)
        else:
            # minibatch training
            for layer, block in zip(self.layers, blocks):
                h = layer(block, h)
        return h

    def inference(self, g, batch_size, device, num_workers, x=None):
        """Minibatch inference of final representation over all node types.

        ***NOTE***
        For node classification, the model is trained to predict on only one node type's
        label.  Therefore, only that type's final representation is meaningful.
        """

        if x is None:
            x = self.embed_layer()

        for l, layer in enumerate(self.layers):
            y = {
                k: th.zeros(
                    g.number_of_nodes(k),
                    self.h_dim if l != len(self.layers) - 1 else self.out_dim)
                for k in g.ntypes}

            sampler = dgl.dataloading.MultiLayerFullNeighborSampler(1)
            dataloader = dgl.dataloading.NodeDataLoader(
                g,
                {k: th.arange(g.number_of_nodes(k)) for k in g.ntypes},
                sampler,
                batch_size=batch_size,
                shuffle=True,
                drop_last=False,
                num_workers=num_workers)

            for input_nodes, output_nodes, blocks in tqdm.tqdm(dataloader):
                block = blocks[0].to(device)

                h = {k: x[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
                h = layer(block, h)

                for k in h.keys():
                    y[k][output_nodes[k]] = h[k].cpu()

            x = y
        return y

# %%
class EntityClassify_HeteroAPI(nn.Module):
    def __init__(self,
                 g,
                 h_dim, out_dim,
                 num_bases,
                 num_hidden_layers=1,
                 dropout=0,
                 use_self_loop=False):
        super(EntityClassify_HeteroAPI, self).__init__()
        self.g = g
        self.h_dim = h_dim
        self.out_dim = out_dim
        self.rel_names = list(set(g.etypes))
        self.rel_names.sort()
        if num_bases < 0 or num_bases > len(self.rel_names):
            self.num_bases = len(self.rel_names)
        else:
            self.num_bases = num_bases
        self.num_hidden_layers = num_hidden_layers
        self.dropout = dropout
        self.use_self_loop = use_self_loop

        self.embed_layer = RelGraphEmbed(g, self.h_dim)
        self.layers = nn.ModuleList()
        # i2h
        self.layers.append(RelGraphConvLayerHeteroAPI(
            self.h_dim, self.h_dim, self.rel_names,
            self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
            dropout=self.dropout, weight=False))
        # h2h
        for i in range(self.num_hidden_layers):
            self.layers.append(RelGraphConvLayerHeteroAPI(
                self.h_dim, self.h_dim, self.rel_names,
                self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
                dropout=self.dropout))
        # h2o
        self.layers.append(RelGraphConvLayerHeteroAPI(
            self.h_dim, self.out_dim, self.rel_names,
            self.num_bases, activation=None,
            self_loop=self.use_self_loop))

    def forward(self, h=None, blocks=None):
        if h is None:
            # full graph training
            h = self.embed_layer()
        if blocks is None:
            # full graph training
            for layer in self.layers:
                h = layer(self.g, h)
        else:
            # minibatch training
            for layer, block in zip(self.layers, blocks):
                h = layer(block, h)
        return h

    def inference(self, g, batch_size, device, num_workers, x=None):
        """Minibatch inference of final representation over all node types.

        ***NOTE***
        For node classification, the model is trained to predict on only one node type's
        label.  Therefore, only that type's final representation is meaningful.
        """

        if x is None:
            x = self.embed_layer()

        for l, layer in enumerate(self.layers):
            y = {
                k: th.zeros(
                    g.number_of_nodes(k),
                    self.h_dim if l != len(self.layers) - 1 else self.out_dim)
                for k in g.ntypes}

            sampler = dgl.dataloading.MultiLayerFullNeighborSampler(1)
            dataloader = dgl.dataloading.NodeDataLoader(
                g,
                {k: th.arange(g.number_of_nodes(k)) for k in g.ntypes},
                sampler,
                batch_size=batch_size,
                shuffle=True,
                drop_last=False,
                num_workers=num_workers)

            for input_nodes, output_nodes, blocks in tqdm.tqdm(dataloader):
                block = blocks[0].to(device)

                h = {k: x[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
                h = layer(block, h)

                for k in h.keys():
                    y[k][output_nodes[k]] = h[k].cpu()

            x = y
        return y

# %% [markdown]
# ### ノード分類の実装
# ここから作ったグラフを使って学習を行う。

# %%
# split dataset into train, validate, test
if args.validation:
    val_idx = train_idx[:len(train_idx) // 5]
    train_idx = train_idx[len(train_idx) // 5:]
else:
    val_idx = train_idx

# %%
# check cuda
use_cuda = args.gpu >= 0 and th.cuda.is_available()
if use_cuda:
    th.cuda.set_device(args.gpu)
    g = g.to('cuda:%d' % args.gpu)
    labels = labels.cuda()
    train_idx = train_idx.cuda()
    test_idx = test_idx.cuda()

# %%
# create model
model = EntityClassify(g,
                       args.n_hidden,
                       num_classes,
                       num_bases=args.n_bases,
                       num_hidden_layers=args.n_layers - 2,
                       dropout=args.dropout,
                       use_self_loop=args.use_self_loop)

# %%
if use_cuda:
        model.cuda()

# %%
# optimizer
optimizer = th.optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.l2norm)

# %%
# training loop
print("start training...")
dur = []
model.train()
for epoch in range(args.n_epochs):
    optimizer.zero_grad()
    if epoch > 5:
        t0 = time.time()
    logits = model()[category]
    loss = F.cross_entropy(logits[train_idx], labels[train_idx])
    loss.backward()
    optimizer.step()
    t1 = time.time()

    if epoch > 5:
        dur.append(t1 - t0)
    train_acc = th.sum(logits[train_idx].argmax(dim=1) == labels[train_idx]).item() / len(train_idx)
    val_loss = F.cross_entropy(logits[val_idx], labels[val_idx])
    val_acc = th.sum(logits[val_idx].argmax(dim=1) == labels[val_idx]).item() / len(val_idx)
    print("Epoch {:05d} | Train Acc: {:.4f} | Train Loss: {:.4f} | Valid Acc: {:.4f} | Valid loss: {:.4f} | Time: {:.4f}".
         format(epoch, train_acc, loss.item(), val_acc, val_loss.item(), np.average(dur)))
print()
if args.model_path is not None:
    th.save(model.state_dict(), args.model_path)

model.eval()
logits = model.forward()[category]
test_loss = F.cross_entropy(logits[test_idx], labels[test_idx])
test_acc = th.sum(logits[test_idx].argmax(dim=1) == labels[test_idx]).item() / len(test_idx)
print("Test Acc: {:.4f} | Test loss: {:.4f}".format(test_acc, test_loss.item()))
print()
# Out:
# start training...
# Epoch 00000 | Train Acc: 0.1329 | Train Loss: 1.3874 | Valid Acc: 0.1329 | Valid loss: 1.3874 | Time: nan
# Epoch 00001 | Train Acc: 0.4564 | Train Loss: 1.3710 | Valid Acc: 0.4564 | Valid loss: 1.3710 | Time: nan
# Epoch 00002 | Train Acc: 0.4566 | Train Loss: 1.3515 | Valid Acc: 0.4566 | Valid loss: 1.3515 | Time: nan
# Epoch 00003 | Train Acc: 0.4566 | Train Loss: 1.3270 | Valid Acc: 0.4566 | Valid loss: 1.3270 | Time: nan
# Epoch 00004 | Train Acc: 0.4566 | Train Loss: 1.2955 | Valid Acc: 0.4566 | Valid loss: 1.2955 | Time: nan
# Epoch 00005 | Train Acc: 0.4567 | Train Loss: 1.2557 | Valid Acc: 0.4567 | Valid loss: 1.2557 | Time: nan
# Epoch 00006 | Train Acc: 0.4569 | Train Loss: 1.2101 | Valid Acc: 0.4569 | Valid loss: 1.2101 | Time: 0.0300
# Epoch 00007 | Train Acc: 0.4569 | Train Loss: 1.1684 | Valid Acc: 0.4569 | Valid loss: 1.1684 | Time: 0.0305
# Epoch 00008 | Train Acc: 0.4569 | Train Loss: 1.1497 | Valid Acc: 0.4569 | Valid loss: 1.1497 | Time: 0.0303
# Epoch 00009 | Train Acc: 0.4569 | Train Loss: 1.1563 | Valid Acc: 0.4569 | Valid loss: 1.1563 | Time: 0.0305
# Epoch 00010 | Train Acc: 0.4569 | Train Loss: 1.1561 | Valid Acc: 0.4569 | Valid loss: 1.1561 | Time: 0.0304
# Epoch 00011 | Train Acc: 0.4623 | Train Loss: 1.1477 | Valid Acc: 0.4623 | Valid loss: 1.1477 | Time: 0.0303
# Epoch 00012 | Train Acc: 0.4561 | Train Loss: 1.1382 | Valid Acc: 0.4561 | Valid loss: 1.1382 | Time: 0.0306
# Epoch 00013 | Train Acc: 0.4257 | Train Loss: 1.1285 | Valid Acc: 0.4257 | Valid loss: 1.1285 | Time: 0.0304
# Epoch 00014 | Train Acc: 0.4223 | Train Loss: 1.1206 | Valid Acc: 0.4223 | Valid loss: 1.1206 | Time: 0.0305
# Epoch 00015 | Train Acc: 0.4363 | Train Loss: 1.1162 | Valid Acc: 0.4363 | Valid loss: 1.1162 | Time: 0.0304
# Epoch 00016 | Train Acc: 0.4740 | Train Loss: 1.1146 | Valid Acc: 0.4740 | Valid loss: 1.1146 | Time: 0.0302
# Epoch 00017 | Train Acc: 0.4775 | Train Loss: 1.1140 | Valid Acc: 0.4775 | Valid loss: 1.1140 | Time: 0.0302
# Epoch 00018 | Train Acc: 0.4667 | Train Loss: 1.1131 | Valid Acc: 0.4667 | Valid loss: 1.1131 | Time: 0.0301
# Epoch 00019 | Train Acc: 0.4606 | Train Loss: 1.1113 | Valid Acc: 0.4606 | Valid loss: 1.1113 | Time: 0.0300
# Epoch 00020 | Train Acc: 0.4584 | Train Loss: 1.1087 | Valid Acc: 0.4584 | Valid loss: 1.1087 | Time: 0.0300
# Epoch 00021 | Train Acc: 0.4580 | Train Loss: 1.1056 | Valid Acc: 0.4580 | Valid loss: 1.1056 | Time: 0.0300
# Epoch 00022 | Train Acc: 0.4584 | Train Loss: 1.1026 | Valid Acc: 0.4584 | Valid loss: 1.1026 | Time: 0.0300
# Epoch 00023 | Train Acc: 0.4585 | Train Loss: 1.0999 | Valid Acc: 0.4585 | Valid loss: 1.0999 | Time: 0.0300
# Epoch 00024 | Train Acc: 0.4587 | Train Loss: 1.0974 | Valid Acc: 0.4587 | Valid loss: 1.0974 | Time: 0.0300
# Epoch 00025 | Train Acc: 0.4590 | Train Loss: 1.0946 | Valid Acc: 0.4590 | Valid loss: 1.0946 | Time: 0.0302
# Epoch 00026 | Train Acc: 0.4628 | Train Loss: 1.0912 | Valid Acc: 0.4628 | Valid loss: 1.0912 | Time: 0.0302
# Epoch 00027 | Train Acc: 0.4721 | Train Loss: 1.0876 | Valid Acc: 0.4721 | Valid loss: 1.0876 | Time: 0.0303
# Epoch 00028 | Train Acc: 0.4878 | Train Loss: 1.0843 | Valid Acc: 0.4878 | Valid loss: 1.0843 | Time: 0.0305
# Epoch 00029 | Train Acc: 0.5015 | Train Loss: 1.0814 | Valid Acc: 0.5015 | Valid loss: 1.0814 | Time: 0.0309
# Epoch 00030 | Train Acc: 0.4985 | Train Loss: 1.0787 | Valid Acc: 0.4985 | Valid loss: 1.0787 | Time: 0.0309
# Epoch 00031 | Train Acc: 0.4979 | Train Loss: 1.0752 | Valid Acc: 0.4979 | Valid loss: 1.0752 | Time: 0.0310
# Epoch 00032 | Train Acc: 0.4979 | Train Loss: 1.0707 | Valid Acc: 0.4979 | Valid loss: 1.0707 | Time: 0.0310
# Epoch 00033 | Train Acc: 0.5031 | Train Loss: 1.0650 | Valid Acc: 0.5031 | Valid loss: 1.0650 | Time: 0.0311
# Epoch 00034 | Train Acc: 0.5105 | Train Loss: 1.0586 | Valid Acc: 0.5105 | Valid loss: 1.0586 | Time: 0.0311
# Epoch 00035 | Train Acc: 0.5176 | Train Loss: 1.0519 | Valid Acc: 0.5176 | Valid loss: 1.0519 | Time: 0.0310
# Epoch 00036 | Train Acc: 0.5253 | Train Loss: 1.0451 | Valid Acc: 0.5253 | Valid loss: 1.0451 | Time: 0.0310
# Epoch 00037 | Train Acc: 0.5289 | Train Loss: 1.0379 | Valid Acc: 0.5289 | Valid loss: 1.0379 | Time: 0.0309
# Epoch 00038 | Train Acc: 0.5318 | Train Loss: 1.0298 | Valid Acc: 0.5318 | Valid loss: 1.0298 | Time: 0.0309
# Epoch 00039 | Train Acc: 0.5380 | Train Loss: 1.0200 | Valid Acc: 0.5380 | Valid loss: 1.0200 | Time: 0.0309
# Epoch 00040 | Train Acc: 0.5462 | Train Loss: 1.0083 | Valid Acc: 0.5462 | Valid loss: 1.0083 | Time: 0.0309
# Epoch 00041 | Train Acc: 0.5572 | Train Loss: 0.9949 | Valid Acc: 0.5572 | Valid loss: 0.9949 | Time: 0.0309
# Epoch 00042 | Train Acc: 0.5645 | Train Loss: 0.9801 | Valid Acc: 0.5645 | Valid loss: 0.9801 | Time: 0.0309
# Epoch 00043 | Train Acc: 0.5759 | Train Loss: 0.9639 | Valid Acc: 0.5759 | Valid loss: 0.9639 | Time: 0.0308
# Epoch 00044 | Train Acc: 0.5870 | Train Loss: 0.9456 | Valid Acc: 0.5870 | Valid loss: 0.9456 | Time: 0.0308
# Epoch 00045 | Train Acc: 0.5970 | Train Loss: 0.9249 | Valid Acc: 0.5970 | Valid loss: 0.9249 | Time: 0.0308
# Epoch 00046 | Train Acc: 0.6102 | Train Loss: 0.9021 | Valid Acc: 0.6102 | Valid loss: 0.9021 | Time: 0.0307
# Epoch 00047 | Train Acc: 0.6207 | Train Loss: 0.8781 | Valid Acc: 0.6207 | Valid loss: 0.8781 | Time: 0.0307
# Epoch 00048 | Train Acc: 0.6336 | Train Loss: 0.8532 | Valid Acc: 0.6336 | Valid loss: 0.8532 | Time: 0.0307
# Epoch 00049 | Train Acc: 0.6458 | Train Loss: 0.8270 | Valid Acc: 0.6458 | Valid loss: 0.8270 | Time: 0.0306
# Epoch 00050 | Train Acc: 0.6590 | Train Loss: 0.7997 | Valid Acc: 0.6590 | Valid loss: 0.7997 | Time: 0.0307
# Epoch 00051 | Train Acc: 0.6690 | Train Loss: 0.7717 | Valid Acc: 0.6690 | Valid loss: 0.7717 | Time: 0.0306
# Epoch 00052 | Train Acc: 0.6791 | Train Loss: 0.7432 | Valid Acc: 0.6791 | Valid loss: 0.7432 | Time: 0.0306
# Epoch 00053 | Train Acc: 0.6914 | Train Loss: 0.7144 | Valid Acc: 0.6914 | Valid loss: 0.7144 | Time: 0.0306
# Epoch 00054 | Train Acc: 0.7046 | Train Loss: 0.6857 | Valid Acc: 0.7046 | Valid loss: 0.6857 | Time: 0.0306
# Epoch 00055 | Train Acc: 0.7133 | Train Loss: 0.6563 | Valid Acc: 0.7133 | Valid loss: 0.6563 | Time: 0.0305
# Epoch 00056 | Train Acc: 0.7253 | Train Loss: 0.6267 | Valid Acc: 0.7253 | Valid loss: 0.6267 | Time: 0.0305
# Epoch 00057 | Train Acc: 0.7394 | Train Loss: 0.5978 | Valid Acc: 0.7394 | Valid loss: 0.5978 | Time: 0.0305
# Epoch 00058 | Train Acc: 0.7531 | Train Loss: 0.5701 | Valid Acc: 0.7531 | Valid loss: 0.5701 | Time: 0.0305
# Epoch 00059 | Train Acc: 0.7631 | Train Loss: 0.5434 | Valid Acc: 0.7631 | Valid loss: 0.5434 | Time: 0.0305
# Epoch 00060 | Train Acc: 0.7730 | Train Loss: 0.5150 | Valid Acc: 0.7730 | Valid loss: 0.5150 | Time: 0.0305
# Epoch 00061 | Train Acc: 0.7856 | Train Loss: 0.4866 | Valid Acc: 0.7856 | Valid loss: 0.4866 | Time: 0.0304
# Epoch 00062 | Train Acc: 0.8034 | Train Loss: 0.4596 | Valid Acc: 0.8034 | Valid loss: 0.4596 | Time: 0.0304
# Epoch 00063 | Train Acc: 0.8130 | Train Loss: 0.4323 | Valid Acc: 0.8130 | Valid loss: 0.4323 | Time: 0.0304
# Epoch 00064 | Train Acc: 0.8310 | Train Loss: 0.4064 | Valid Acc: 0.8310 | Valid loss: 0.4064 | Time: 0.0304
# Epoch 00065 | Train Acc: 0.8359 | Train Loss: 0.3825 | Valid Acc: 0.8359 | Valid loss: 0.3825 | Time: 0.0304
# Epoch 00066 | Train Acc: 0.8547 | Train Loss: 0.3590 | Valid Acc: 0.8547 | Valid loss: 0.3590 | Time: 0.0304
# Epoch 00067 | Train Acc: 0.8632 | Train Loss: 0.3377 | Valid Acc: 0.8632 | Valid loss: 0.3377 | Time: 0.0304
# Epoch 00068 | Train Acc: 0.8738 | Train Loss: 0.3188 | Valid Acc: 0.8738 | Valid loss: 0.3188 | Time: 0.0304
# Epoch 00069 | Train Acc: 0.8806 | Train Loss: 0.3011 | Valid Acc: 0.8806 | Valid loss: 0.3011 | Time: 0.0304
# Epoch 00070 | Train Acc: 0.8849 | Train Loss: 0.2847 | Valid Acc: 0.8849 | Valid loss: 0.2847 | Time: 0.0304
# Epoch 00071 | Train Acc: 0.8909 | Train Loss: 0.2705 | Valid Acc: 0.8909 | Valid loss: 0.2705 | Time: 0.0304
# Epoch 00072 | Train Acc: 0.8950 | Train Loss: 0.2577 | Valid Acc: 0.8950 | Valid loss: 0.2577 | Time: 0.0304
# Epoch 00073 | Train Acc: 0.9001 | Train Loss: 0.2461 | Valid Acc: 0.9001 | Valid loss: 0.2461 | Time: 0.0304
# Epoch 00074 | Train Acc: 0.9041 | Train Loss: 0.2354 | Valid Acc: 0.9041 | Valid loss: 0.2354 | Time: 0.0304
# Epoch 00075 | Train Acc: 0.9089 | Train Loss: 0.2251 | Valid Acc: 0.9089 | Valid loss: 0.2251 | Time: 0.0304
# Epoch 00076 | Train Acc: 0.9128 | Train Loss: 0.2151 | Valid Acc: 0.9128 | Valid loss: 0.2151 | Time: 0.0303
# Epoch 00077 | Train Acc: 0.9157 | Train Loss: 0.2063 | Valid Acc: 0.9157 | Valid loss: 0.2063 | Time: 0.0303
# Epoch 00078 | Train Acc: 0.9213 | Train Loss: 0.1987 | Valid Acc: 0.9213 | Valid loss: 0.1987 | Time: 0.0303
# Epoch 00079 | Train Acc: 0.9223 | Train Loss: 0.1912 | Valid Acc: 0.9223 | Valid loss: 0.1912 | Time: 0.0303
# Epoch 00080 | Train Acc: 0.9250 | Train Loss: 0.1843 | Valid Acc: 0.9250 | Valid loss: 0.1843 | Time: 0.0303
# Epoch 00081 | Train Acc: 0.9280 | Train Loss: 0.1780 | Valid Acc: 0.9280 | Valid loss: 0.1780 | Time: 0.0303
# Epoch 00082 | Train Acc: 0.9291 | Train Loss: 0.1719 | Valid Acc: 0.9291 | Valid loss: 0.1719 | Time: 0.0303
# Epoch 00083 | Train Acc: 0.9311 | Train Loss: 0.1666 | Valid Acc: 0.9311 | Valid loss: 0.1666 | Time: 0.0303
# Epoch 00084 | Train Acc: 0.9332 | Train Loss: 0.1618 | Valid Acc: 0.9332 | Valid loss: 0.1618 | Time: 0.0303
# Epoch 00085 | Train Acc: 0.9345 | Train Loss: 0.1572 | Valid Acc: 0.9345 | Valid loss: 0.1572 | Time: 0.0303
# Epoch 00086 | Train Acc: 0.9352 | Train Loss: 0.1525 | Valid Acc: 0.9352 | Valid loss: 0.1525 | Time: 0.0302
# Epoch 00087 | Train Acc: 0.9381 | Train Loss: 0.1476 | Valid Acc: 0.9381 | Valid loss: 0.1476 | Time: 0.0302
# Epoch 00088 | Train Acc: 0.9407 | Train Loss: 0.1443 | Valid Acc: 0.9407 | Valid loss: 0.1443 | Time: 0.0303
# Epoch 00089 | Train Acc: 0.9412 | Train Loss: 0.1412 | Valid Acc: 0.9412 | Valid loss: 0.1412 | Time: 0.0303
# Epoch 00090 | Train Acc: 0.9437 | Train Loss: 0.1372 | Valid Acc: 0.9437 | Valid loss: 0.1372 | Time: 0.0302
# Epoch 00091 | Train Acc: 0.9456 | Train Loss: 0.1332 | Valid Acc: 0.9456 | Valid loss: 0.1332 | Time: 0.0302
# Epoch 00092 | Train Acc: 0.9473 | Train Loss: 0.1302 | Valid Acc: 0.9473 | Valid loss: 0.1302 | Time: 0.0302
# Epoch 00093 | Train Acc: 0.9484 | Train Loss: 0.1277 | Valid Acc: 0.9484 | Valid loss: 0.1277 | Time: 0.0302
# Epoch 00094 | Train Acc: 0.9491 | Train Loss: 0.1248 | Valid Acc: 0.9491 | Valid loss: 0.1248 | Time: 0.0302
# Epoch 00095 | Train Acc: 0.9504 | Train Loss: 0.1215 | Valid Acc: 0.9504 | Valid loss: 0.1215 | Time: 0.0302
# Epoch 00096 | Train Acc: 0.9523 | Train Loss: 0.1185 | Valid Acc: 0.9523 | Valid loss: 0.1185 | Time: 0.0303
# Epoch 00097 | Train Acc: 0.9530 | Train Loss: 0.1161 | Valid Acc: 0.9530 | Valid loss: 0.1161 | Time: 0.0303
# Epoch 00098 | Train Acc: 0.9536 | Train Loss: 0.1137 | Valid Acc: 0.9536 | Valid loss: 0.1137 | Time: 0.0302
# Epoch 00099 | Train Acc: 0.9548 | Train Loss: 0.1110 | Valid Acc: 0.9548 | Valid loss: 0.1110 | Time: 0.0302
#
# Test Acc: 0.7333 | Test loss: 10.0724

# %%
from collections import defaultdict
import argparse
import torch as th
import torch.nn as nn
import torch.nn.functional as F
import dgl
import dgl.function as fn
import dgl.nn as dglnn
import tqdm
from dgl.data.rdf import AIFBDataset, MUTAGDataset, BGSDataset, AMDataset
import pandas as pd
import numpy as np
import random as rd
import time

# %%
parser = argparse.ArgumentParser(description='RGCN')
parser.add_argument("--dropout", type=float, default=0,
        help="dropout probability")
parser.add_argument("--n-hidden", type=int, default=16,
        help="number of hidden units")
parser.add_argument("--gpu", type=int, default=-1,
        help="gpu")
parser.add_argument("--lr", type=float, default=1e-2,
        help="learning rate")
parser.add_argument("--n-bases", type=int, default=-1,
        help="number of filter weight matrices, default: -1 [use all]")
parser.add_argument("--n-layers", type=int, default=2,
        help="number of propagation rounds")
parser.add_argument("-e", "--n-epochs", type=int, default=50,
        help="number of training epochs")
parser.add_argument("--model_path", type=str, default=None,
        help='path for save the model')
parser.add_argument("--l2norm", type=float, default=0,
        help="l2 norm coef")
parser.add_argument("--use-self-loop", default=False, action='store_true',
        help="include self feature as a special relation")
fp = parser.add_mutually_exclusive_group(required=False)
fp.add_argument('--validation', dest='validation', action='store_true')
fp.add_argument('--testing', dest='validation', action='store_false')
parser.set_defaults(validation=True)

args = parser.parse_args(args=['-e','100','--n-layers','5','--testing','--gpu','0'])

# %% [markdown]
# ### CSVファイルからテンソルへの変換
# daskというライブラリを経由して、テンソルへと変換
# daskは大きなデータを扱う際にアシストしてくれるもの。学習の際に、サイズが大きいものをうまく扱う？
# ```
# import dask.dataframe as dd
# print("Loading CSV...")
# test = dd.read_csv("position-pass-position.csv", encoding = "UTF-8")
#
# print("Converting to Tensor...")
# test_tensor = th.tensor(test)
# ```

# %% [markdown]
# ### うまく行かなったのPandasで

# %% [markdown]
# ### グラフの構築
# 作ったテンソルをDGLに読み込ませるだけ

# %%
rel = pd.read_csv('data\STD1\data.csv')
id = pd.read_csv('data\STD1\list.csv')
pos_null = pd.read_csv('data\STD1\pn.csv')
null_pos = pd.read_csv('data\STD1\_np.csv')
t_link = pd.read_csv('data\STD1\link.csv')
mini = pd.read_csv('data\STD1\mini\list.csv')

# %%
graphdata = {
    ('position', 'pass','position'):(th.tensor(rel['fromid']),th.tensor(rel['toid'])),
    ('position','temporal','position'):(th.tensor(t_link['fromid']),th.tensor(t_link['toid'])),
    ('position','temporal','null'):(th.tensor(pos_null['fromid']),th.tensor(pos_null['nullid'])),
    ('null','temporal','position'):(th.tensor(null_pos['nullid']),th.tensor(null_pos['toid']))
}
g = dgl.heterograph(graphdata)

# %%
#label数２５
labels = th.tensor(id['posid'])
num_classes = 25 #len(g.ntypes)
"""
#label数４
labels = th.tensor(id['newpos'])
num_classes = 4 #len(g.ntypes)
"""
"""
#label数８
labels = th.tensor(id['8pos'])
num_classes = 8 #len(g.ntypes)
"""

# %%
category = 'position'
mask_wt = 0.7
final_num = len(mini)
num_node = g.num_nodes(category) - final_num

mask = [1] * int(num_node * mask_wt) + [0] * (num_node - int(num_node * mask_wt))
rd.shuffle(mask)
mask = mask + [0] * final_num

mask_wt = 0.2
mask_tr = [1] * int(final_num * mask_wt) + [0] * (final_num - int(final_num * mask_wt))
rd.shuffle(mask_tr)
mask_tr = [0] * (num_node - final_num) + mask_tr

train_mask = th.tensor(mask)
test_mask = th.tensor(mask_tr)
train_idx = th.nonzero(train_mask, as_tuple=False).squeeze()
test_idx = th.nonzero(test_mask, as_tuple=False).squeeze()
category_id = category
for i, ntype in enumerate(g.ntypes):
    if ntype == category:
        category_id = i

# %% [markdown]
# ### モデルの定義
# 今回はサンプルコードの中から`RelGraphConv`を引用する。使わないやつごと引用した

# %%
class RelGraphConvLayer(nn.Module):
    r"""Relational graph convolution layer.

    Parameters
    ----------
    in_feat : int
        Input feature size.
    out_feat : int
        Output feature size.
    rel_names : list[str]
        Relation names.
    num_bases : int, optional
        Number of bases. If is none, use number of relations. Default: None.
    weight : bool, optional
        True if a linear layer is applied after message passing. Default: True
    bias : bool, optional
        True if bias is added. Default: True
    activation : callable, optional
        Activation function. Default: None
    self_loop : bool, optional
        True to include self loop message. Default: False
    dropout : float, optional
        Dropout rate. Default: 0.0
    """
    def __init__(self,
                 in_feat,
                 out_feat,
                 rel_names,
                 num_bases,
                 *,
                 weight=True,
                 bias=True,
                 activation=None,
                 self_loop=False,
                 dropout=0.0):
        super(RelGraphConvLayer, self).__init__()
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.rel_names = rel_names
        self.num_bases = num_bases
        self.bias = bias
        self.activation = activation
        self.self_loop = self_loop

        self.conv = dglnn.HeteroGraphConv({
                rel : dglnn.GraphConv(in_feat, out_feat, norm='right', weight=False, bias=False)
                for rel in rel_names
            })

        self.use_weight = weight
        self.use_basis = num_bases < len(self.rel_names) and weight
        if self.use_weight:
            if self.use_basis:
                self.basis = dglnn.WeightBasis((in_feat, out_feat), num_bases, len(self.rel_names))
            else:
                self.weight = nn.Parameter(th.Tensor(len(self.rel_names), in_feat, out_feat))
                nn.init.xavier_uniform_(self.weight, gain=nn.init.calculate_gain('relu'))

        # bias
        if bias:
            self.h_bias = nn.Parameter(th.Tensor(out_feat))
            nn.init.zeros_(self.h_bias)

        # weight for self loop
        if self.self_loop:
            self.loop_weight = nn.Parameter(th.Tensor(in_feat, out_feat))
            nn.init.xavier_uniform_(self.loop_weight,
                                    gain=nn.init.calculate_gain('relu'))

        self.dropout = nn.Dropout(dropout)

    def forward(self, g, inputs):
        """Forward computation

        Parameters
        ----------
        g : DGLHeteroGraph
            Input graph.
        inputs : dict[str, torch.Tensor]
            Node feature for each node type.

        Returns
        -------
        dict[str, torch.Tensor]
            New node features for each node type.
        """
        g = g.local_var()
        if self.use_weight:
            weight = self.basis() if self.use_basis else self.weight
            wdict = {self.rel_names[i] : {'weight' : w.squeeze(0)}
                     for i, w in enumerate(th.split(weight, 1, dim=0))}
        else:
            wdict = {}

        if g.is_block:
            inputs_src = inputs
            inputs_dst = {k: v[:g.number_of_dst_nodes(k)] for k, v in inputs.items()}
        else:
            inputs_src = inputs_dst = inputs

        hs = self.conv(g, inputs, mod_kwargs=wdict)

        def _apply(ntype, h):
            if self.self_loop:
                h = h + th.matmul(inputs_dst[ntype], self.loop_weight)
            if self.bias:
                h = h + self.h_bias
            if self.activation:
                h = self.activation(h)
            return self.dropout(h)
        return {ntype : _apply(ntype, h) for ntype, h in hs.items()}

# %%
class RelGraphConvLayerHeteroAPI(nn.Module):
    r"""Relational graph convolution layer.

    Parameters
    ----------
    in_feat : int
        Input feature size.
    out_feat : int
        Output feature size.
    rel_names : list[str]
        Relation names.
    num_bases : int, optional
        Number of bases. If is none, use number of relations. Default: None.
    weight : bool, optional
        True if a linear layer is applied after message passing. Default: True
    bias : bool, optional
        True if bias is added. Default: True
    activation : callable, optional
        Activation function. Default: None
    self_loop : bool, optional
        True to include self loop message. Default: False
    dropout : float, optional
        Dropout rate. Default: 0.0
    """
    def __init__(self,
                 in_feat,
                 out_feat,
                 rel_names,
                 num_bases,
                 *,
                 weight=True,
                 bias=True,
                 activation=None,
                 self_loop=False,
                 dropout=0.0):
        super(RelGraphConvLayerHeteroAPI, self).__init__()
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.rel_names = rel_names
        self.num_bases = num_bases
        self.bias = bias
        self.activation = activation
        self.self_loop = self_loop

        self.use_weight = weight
        self.use_basis = num_bases < len(self.rel_names) and weight
        if self.use_weight:
            if self.use_basis:
                self.basis = dglnn.WeightBasis((in_feat, out_feat), num_bases, len(self.rel_names))
            else:
                self.weight = nn.Parameter(th.Tensor(len(self.rel_names), in_feat, out_feat))
                nn.init.xavier_uniform_(self.weight, gain=nn.init.calculate_gain('relu'))

        # bias
        if bias:
            self.h_bias = nn.Parameter(th.Tensor(out_feat))
            nn.init.zeros_(self.h_bias)

        # weight for self loop
        if self.self_loop:
            self.loop_weight = nn.Parameter(th.Tensor(in_feat, out_feat))
            nn.init.xavier_uniform_(self.loop_weight,
                                    gain=nn.init.calculate_gain('relu'))

        self.dropout = nn.Dropout(dropout)

    def forward(self, g, inputs):
        """Forward computation

        Parameters
        ----------
        g : DGLHeteroGraph
            Input graph.
        inputs : dict[str, torch.Tensor]
            Node feature for each node type.

        Returns
        -------
        dict[str, torch.Tensor]
            New node features for each node type.
        """
        g = g.local_var()
        if self.use_weight:
            weight = self.basis() if self.use_basis else self.weight
            wdict = {self.rel_names[i] : {'weight' : w.squeeze(0)}
                     for i, w in enumerate(th.split(weight, 1, dim=0))}
        else:
            wdict = {}

        inputs_src = inputs_dst = inputs

        for srctype,_,_ in g.canonical_etypes:
            g.nodes[srctype].data['h'] = inputs[srctype]

        if self.use_weight:
            g.apply_edges(fn.copy_u('h', 'm'))
            m = g.edata['m']
            for rel in g.canonical_etypes:
                _, etype, _ = rel
                g.edges[rel].data['h*w_r'] =  th.matmul(m[rel], wdict[etype]['weight'])
        else:
            g.apply_edges(fn.copy_u('h', 'h*w_r'))

        g.update_all(fn.copy_e('h*w_r', 'm'), fn.sum('m', 'h'))

        def _apply(ntype):
            h = g.nodes[ntype].data['h']
            if self.self_loop:
                h = h + th.matmul(inputs_dst[ntype], self.loop_weight)
            if self.bias:
                h = h + self.h_bias
            if self.activation:
                h = self.activation(h)
            return self.dropout(h)
        return {ntype : _apply(ntype) for ntype in g.dsttypes}

# %%
class RelGraphEmbed(nn.Module):
    r"""Embedding layer for featureless heterograph."""
    def __init__(self,
                 g,
                 embed_size,
                 embed_name='embed',
                 activation=None,
                 dropout=0.0):
        super(RelGraphEmbed, self).__init__()
        self.g = g
        self.embed_size = embed_size
        self.embed_name = embed_name
        self.activation = activation
        self.dropout = nn.Dropout(dropout)

        # create weight embeddings for each node for each relation
        self.embeds = nn.ParameterDict()
        for ntype in g.ntypes:
            embed = nn.Parameter(th.Tensor(g.number_of_nodes(ntype), self.embed_size))
            nn.init.xavier_uniform_(embed, gain=nn.init.calculate_gain('relu'))
            self.embeds[ntype] = embed

    def forward(self, block=None):
        """Forward computation

        Parameters
        ----------
        block : DGLHeteroGraph, optional
            If not specified, directly return the full graph with embeddings stored in
            :attr:`embed_name`. Otherwise, extract and store the embeddings to the block
            graph and return.

        Returns
        -------
        DGLHeteroGraph
            The block graph fed with embeddings.
        """
        return self.embeds

# %%
class EntityClassify(nn.Module):
    def __init__(self,
                 g,
                 h_dim, out_dim,
                 num_bases,
                 num_hidden_layers=1,
                 dropout=0,
                 use_self_loop=False):
        super(EntityClassify, self).__init__()
        self.g = g
        self.h_dim = h_dim
        self.out_dim = out_dim
        self.rel_names = list(set(g.etypes))
        self.rel_names.sort()
        if num_bases < 0 or num_bases > len(self.rel_names):
            self.num_bases = len(self.rel_names)
        else:
            self.num_bases = num_bases
        self.num_hidden_layers = num_hidden_layers
        self.dropout = dropout
        self.use_self_loop = use_self_loop

        self.embed_layer = RelGraphEmbed(g, self.h_dim)
        self.layers = nn.ModuleList()
        # i2h
        self.layers.append(RelGraphConvLayer(
            self.h_dim, self.h_dim, self.rel_names,
            self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
            dropout=self.dropout, weight=False))
        # h2h
        for i in range(self.num_hidden_layers):
            self.layers.append(RelGraphConvLayer(
                self.h_dim, self.h_dim, self.rel_names,
                self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
                dropout=self.dropout))
        # h2o
        self.layers.append(RelGraphConvLayer(
            self.h_dim, self.out_dim, self.rel_names,
            self.num_bases, activation=None,
            self_loop=self.use_self_loop))

    def forward(self, h=None, blocks=None):
        if h is None:
            # full graph training
            h = self.embed_layer()
        if blocks is None:
            # full graph training
            for layer in self.layers:
                h = layer(self.g, h)
        else:
            # minibatch training
            for layer, block in zip(self.layers, blocks):
                h = layer(block, h)
        return h

    def inference(self, g, batch_size, device, num_workers, x=None):
        """Minibatch inference of final representation over all node types.

        ***NOTE***
        For node classification, the model is trained to predict on only one node type's
        label.  Therefore, only that type's final representation is meaningful.
        """

        if x is None:
            x = self.embed_layer()

        for l, layer in enumerate(self.layers):
            y = {
                k: th.zeros(
                    g.number_of_nodes(k),
                    self.h_dim if l != len(self.layers) - 1 else self.out_dim)
                for k in g.ntypes}

            sampler = dgl.dataloading.MultiLayerFullNeighborSampler(1)
            dataloader = dgl.dataloading.NodeDataLoader(
                g,
                {k: th.arange(g.number_of_nodes(k)) for k in g.ntypes},
                sampler,
                batch_size=batch_size,
                shuffle=True,
                drop_last=False,
                num_workers=num_workers)

            for input_nodes, output_nodes, blocks in tqdm.tqdm(dataloader):
                block = blocks[0].to(device)

                h = {k: x[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
                h = layer(block, h)

                for k in h.keys():
                    y[k][output_nodes[k]] = h[k].cpu()

            x = y
        return y

# %%
class EntityClassify_HeteroAPI(nn.Module):
    def __init__(self,
                 g,
                 h_dim, out_dim,
                 num_bases,
                 num_hidden_layers=1,
                 dropout=0,
                 use_self_loop=False):
        super(EntityClassify_HeteroAPI, self).__init__()
        self.g = g
        self.h_dim = h_dim
        self.out_dim = out_dim
        self.rel_names = list(set(g.etypes))
        self.rel_names.sort()
        if num_bases < 0 or num_bases > len(self.rel_names):
            self.num_bases = len(self.rel_names)
        else:
            self.num_bases = num_bases
        self.num_hidden_layers = num_hidden_layers
        self.dropout = dropout
        self.use_self_loop = use_self_loop

        self.embed_layer = RelGraphEmbed(g, self.h_dim)
        self.layers = nn.ModuleList()
        # i2h
        self.layers.append(RelGraphConvLayerHeteroAPI(
            self.h_dim, self.h_dim, self.rel_names,
            self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
            dropout=self.dropout, weight=False))
        # h2h
        for i in range(self.num_hidden_layers):
            self.layers.append(RelGraphConvLayerHeteroAPI(
                self.h_dim, self.h_dim, self.rel_names,
                self.num_bases, activation=F.relu, self_loop=self.use_self_loop,
                dropout=self.dropout))
        # h2o
        self.layers.append(RelGraphConvLayerHeteroAPI(
            self.h_dim, self.out_dim, self.rel_names,
            self.num_bases, activation=None,
            self_loop=self.use_self_loop))

    def forward(self, h=None, blocks=None):
        if h is None:
            # full graph training
            h = self.embed_layer()
        if blocks is None:
            # full graph training
            for layer in self.layers:
                h = layer(self.g, h)
        else:
            # minibatch training
            for layer, block in zip(self.layers, blocks):
                h = layer(block, h)
        return h

    def inference(self, g, batch_size, device, num_workers, x=None):
        """Minibatch inference of final representation over all node types.

        ***NOTE***
        For node classification, the model is trained to predict on only one node type's
        label.  Therefore, only that type's final representation is meaningful.
        """

        if x is None:
            x = self.embed_layer()

        for l, layer in enumerate(self.layers):
            y = {
                k: th.zeros(
                    g.number_of_nodes(k),
                    self.h_dim if l != len(self.layers) - 1 else self.out_dim)
                for k in g.ntypes}

            sampler = dgl.dataloading.MultiLayerFullNeighborSampler(1)
            dataloader = dgl.dataloading.NodeDataLoader(
                g,
                {k: th.arange(g.number_of_nodes(k)) for k in g.ntypes},
                sampler,
                batch_size=batch_size,
                shuffle=True,
                drop_last=False,
                num_workers=num_workers)

            for input_nodes, output_nodes, blocks in tqdm.tqdm(dataloader):
                block = blocks[0].to(device)

                h = {k: x[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
                h = layer(block, h)

                for k in h.keys():
                    y[k][output_nodes[k]] = h[k].cpu()

            x = y
        return y

# %% [markdown]
# ### ノード分類の実装
# ここから作ったグラフを使って学習を行う。

# %%
# split dataset into train, validate, test
if args.validation:
    val_idx = train_idx[:len(train_idx) // 5]
    train_idx = train_idx[len(train_idx) // 5:]
else:
    val_idx = train_idx

# %%
# check cuda
use_cuda = args.gpu >= 0 and th.cuda.is_available()
if use_cuda:
    th.cuda.set_device(args.gpu)
    g = g.to('cuda:%d' % args.gpu)
    labels = labels.cuda()
    train_idx = train_idx.cuda()
    test_idx = test_idx.cuda()

# %%
# create model
model = EntityClassify(g,
                       args.n_hidden,
                       num_classes,
                       num_bases=args.n_bases,
                       num_hidden_layers=args.n_layers - 2,
                       dropout=args.dropout,
                       use_self_loop=args.use_self_loop)

# %%
if use_cuda:
        model.cuda()

# %%
# optimizer
optimizer = th.optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.l2norm)

# %%
# training loop
print("start training...")
dur = []
model.train()
for epoch in range(args.n_epochs):
    optimizer.zero_grad()
    if epoch > 5:
        t0 = time.time()
    logits = model()[category]
    loss = F.cross_entropy(logits[train_idx], labels[train_idx])
    loss.backward()
    optimizer.step()
    t1 = time.time()

    if epoch > 5:
        dur.append(t1 - t0)
    train_acc = th.sum(logits[train_idx].argmax(dim=1) == labels[train_idx]).item() / len(train_idx)
    val_loss = F.cross_entropy(logits[val_idx], labels[val_idx])
    val_acc = th.sum(logits[val_idx].argmax(dim=1) == labels[val_idx]).item() / len(val_idx)
    print("Epoch {:05d} | Train Acc: {:.4f} | Train Loss: {:.4f} | Valid Acc: {:.4f} | Valid loss: {:.4f} | Time: {:.4f}".
         format(epoch, train_acc, loss.item(), val_acc, val_loss.item(), np.average(dur)))
print()
if args.model_path is not None:
    th.save(model.state_dict(), args.model_path)

model.eval()
logits = model.forward()[category]
test_loss = F.cross_entropy(logits[test_idx], labels[test_idx])
test_acc = th.sum(logits[test_idx].argmax(dim=1) == labels[test_idx]).item() / len(test_idx)
print("Test Acc: {:.4f} | Test loss: {:.4f}".format(test_acc, test_loss.item()))
print()
# Out:
# start training...
# Epoch 00000 | Train Acc: 0.1173 | Train Loss: 2.0795 | Valid Acc: 0.1173 | Valid loss: 2.0795 | Time: nan
# Epoch 00001 | Train Acc: 0.2000 | Train Loss: 2.0733 | Valid Acc: 0.2000 | Valid loss: 2.0733 | Time: nan
# Epoch 00002 | Train Acc: 0.2007 | Train Loss: 2.0657 | Valid Acc: 0.2007 | Valid loss: 2.0657 | Time: nan
# Epoch 00003 | Train Acc: 0.2028 | Train Loss: 2.0558 | Valid Acc: 0.2028 | Valid loss: 2.0558 | Time: nan
# Epoch 00004 | Train Acc: 0.2034 | Train Loss: 2.0429 | Valid Acc: 0.2034 | Valid loss: 2.0429 | Time: nan
# Epoch 00005 | Train Acc: 0.2032 | Train Loss: 2.0269 | Valid Acc: 0.2032 | Valid loss: 2.0269 | Time: nan
# Epoch 00006 | Train Acc: 0.2038 | Train Loss: 2.0094 | Valid Acc: 0.2038 | Valid loss: 2.0094 | Time: 0.0325
# Epoch 00007 | Train Acc: 0.2052 | Train Loss: 1.9973 | Valid Acc: 0.2052 | Valid loss: 1.9973 | Time: 0.0316
# Epoch 00008 | Train Acc: 0.2144 | Train Loss: 1.9986 | Valid Acc: 0.2144 | Valid loss: 1.9986 | Time: 0.0314
# Epoch 00009 | Train Acc: 0.2323 | Train Loss: 1.9933 | Valid Acc: 0.2323 | Valid loss: 1.9933 | Time: 0.0313
# Epoch 00010 | Train Acc: 0.2252 | Train Loss: 1.9819 | Valid Acc: 0.2252 | Valid loss: 1.9819 | Time: 0.0311
# Epoch 00011 | Train Acc: 0.2206 | Train Loss: 1.9737 | Valid Acc: 0.2206 | Valid loss: 1.9737 | Time: 0.0309
# Epoch 00012 | Train Acc: 0.2215 | Train Loss: 1.9694 | Valid Acc: 0.2215 | Valid loss: 1.9694 | Time: 0.0306
# Epoch 00013 | Train Acc: 0.2261 | Train Loss: 1.9661 | Valid Acc: 0.2261 | Valid loss: 1.9661 | Time: 0.0306
# Epoch 00014 | Train Acc: 0.2314 | Train Loss: 1.9616 | Valid Acc: 0.2314 | Valid loss: 1.9616 | Time: 0.0308
# Epoch 00015 | Train Acc: 0.2371 | Train Loss: 1.9553 | Valid Acc: 0.2371 | Valid loss: 1.9553 | Time: 0.0307
# Epoch 00016 | Train Acc: 0.2410 | Train Loss: 1.9480 | Valid Acc: 0.2410 | Valid loss: 1.9480 | Time: 0.0305
# Epoch 00017 | Train Acc: 0.2404 | Train Loss: 1.9414 | Valid Acc: 0.2404 | Valid loss: 1.9414 | Time: 0.0306
# Epoch 00018 | Train Acc: 0.2412 | Train Loss: 1.9354 | Valid Acc: 0.2412 | Valid loss: 1.9354 | Time: 0.0305
# Epoch 00019 | Train Acc: 0.2428 | Train Loss: 1.9281 | Valid Acc: 0.2428 | Valid loss: 1.9281 | Time: 0.0305
# Epoch 00020 | Train Acc: 0.2450 | Train Loss: 1.9183 | Valid Acc: 0.2450 | Valid loss: 1.9183 | Time: 0.0304
# Epoch 00021 | Train Acc: 0.2473 | Train Loss: 1.9074 | Valid Acc: 0.2473 | Valid loss: 1.9074 | Time: 0.0304
# Epoch 00022 | Train Acc: 0.2512 | Train Loss: 1.8963 | Valid Acc: 0.2512 | Valid loss: 1.8963 | Time: 0.0303
# Epoch 00023 | Train Acc: 0.2535 | Train Loss: 1.8830 | Valid Acc: 0.2535 | Valid loss: 1.8830 | Time: 0.0303
# Epoch 00024 | Train Acc: 0.2572 | Train Loss: 1.8666 | Valid Acc: 0.2572 | Valid loss: 1.8666 | Time: 0.0304
# Epoch 00025 | Train Acc: 0.2634 | Train Loss: 1.8489 | Valid Acc: 0.2634 | Valid loss: 1.8489 | Time: 0.0304
# Epoch 00026 | Train Acc: 0.2706 | Train Loss: 1.8302 | Valid Acc: 0.2706 | Valid loss: 1.8302 | Time: 0.0304
# Epoch 00027 | Train Acc: 0.2791 | Train Loss: 1.8080 | Valid Acc: 0.2791 | Valid loss: 1.8080 | Time: 0.0304
# Epoch 00028 | Train Acc: 0.2951 | Train Loss: 1.7830 | Valid Acc: 0.2951 | Valid loss: 1.7830 | Time: 0.0303
# Epoch 00029 | Train Acc: 0.3098 | Train Loss: 1.7546 | Valid Acc: 0.3098 | Valid loss: 1.7546 | Time: 0.0303
# Epoch 00030 | Train Acc: 0.3251 | Train Loss: 1.7229 | Valid Acc: 0.3251 | Valid loss: 1.7229 | Time: 0.0303
# Epoch 00031 | Train Acc: 0.3421 | Train Loss: 1.6868 | Valid Acc: 0.3421 | Valid loss: 1.6868 | Time: 0.0302
# Epoch 00032 | Train Acc: 0.3711 | Train Loss: 1.6465 | Valid Acc: 0.3711 | Valid loss: 1.6465 | Time: 0.0302
# Epoch 00033 | Train Acc: 0.3971 | Train Loss: 1.6016 | Valid Acc: 0.3971 | Valid loss: 1.6016 | Time: 0.0302
# Epoch 00034 | Train Acc: 0.4201 | Train Loss: 1.5533 | Valid Acc: 0.4201 | Valid loss: 1.5533 | Time: 0.0302
# Epoch 00035 | Train Acc: 0.4461 | Train Loss: 1.5054 | Valid Acc: 0.4461 | Valid loss: 1.5054 | Time: 0.0302
# Epoch 00036 | Train Acc: 0.4492 | Train Loss: 1.4563 | Valid Acc: 0.4492 | Valid loss: 1.4563 | Time: 0.0302
# Epoch 00037 | Train Acc: 0.4784 | Train Loss: 1.4095 | Valid Acc: 0.4784 | Valid loss: 1.4095 | Time: 0.0302
# Epoch 00038 | Train Acc: 0.4910 | Train Loss: 1.3571 | Valid Acc: 0.4910 | Valid loss: 1.3571 | Time: 0.0301
# Epoch 00039 | Train Acc: 0.5170 | Train Loss: 1.3036 | Valid Acc: 0.5170 | Valid loss: 1.3036 | Time: 0.0301
# Epoch 00040 | Train Acc: 0.5355 | Train Loss: 1.2544 | Valid Acc: 0.5355 | Valid loss: 1.2544 | Time: 0.0301
# Epoch 00041 | Train Acc: 0.5496 | Train Loss: 1.2068 | Valid Acc: 0.5496 | Valid loss: 1.2068 | Time: 0.0301
# Epoch 00042 | Train Acc: 0.5646 | Train Loss: 1.1673 | Valid Acc: 0.5646 | Valid loss: 1.1673 | Time: 0.0301
# Epoch 00043 | Train Acc: 0.5752 | Train Loss: 1.1329 | Valid Acc: 0.5752 | Valid loss: 1.1329 | Time: 0.0301
# Epoch 00044 | Train Acc: 0.6115 | Train Loss: 1.0691 | Valid Acc: 0.6115 | Valid loss: 1.0691 | Time: 0.0302
# Epoch 00045 | Train Acc: 0.6275 | Train Loss: 1.0319 | Valid Acc: 0.6275 | Valid loss: 1.0319 | Time: 0.0302
# Epoch 00046 | Train Acc: 0.6332 | Train Loss: 0.9989 | Valid Acc: 0.6332 | Valid loss: 0.9989 | Time: 0.0302
# Epoch 00047 | Train Acc: 0.6551 | Train Loss: 0.9442 | Valid Acc: 0.6551 | Valid loss: 0.9442 | Time: 0.0301
# Epoch 00048 | Train Acc: 0.6681 | Train Loss: 0.9184 | Valid Acc: 0.6681 | Valid loss: 0.9184 | Time: 0.0301
# Epoch 00049 | Train Acc: 0.6812 | Train Loss: 0.8787 | Valid Acc: 0.6812 | Valid loss: 0.8787 | Time: 0.0301
# Epoch 00050 | Train Acc: 0.6999 | Train Loss: 0.8401 | Valid Acc: 0.6999 | Valid loss: 0.8401 | Time: 0.0302
# Epoch 00051 | Train Acc: 0.7135 | Train Loss: 0.8117 | Valid Acc: 0.7135 | Valid loss: 0.8117 | Time: 0.0301
# Epoch 00052 | Train Acc: 0.7276 | Train Loss: 0.7708 | Valid Acc: 0.7276 | Valid loss: 0.7708 | Time: 0.0301
# Epoch 00053 | Train Acc: 0.7354 | Train Loss: 0.7472 | Valid Acc: 0.7354 | Valid loss: 0.7472 | Time: 0.0301
# Epoch 00054 | Train Acc: 0.7532 | Train Loss: 0.7093 | Valid Acc: 0.7532 | Valid loss: 0.7093 | Time: 0.0301
# Epoch 00055 | Train Acc: 0.7639 | Train Loss: 0.6865 | Valid Acc: 0.7639 | Valid loss: 0.6865 | Time: 0.0301
# Epoch 00056 | Train Acc: 0.7714 | Train Loss: 0.6559 | Valid Acc: 0.7714 | Valid loss: 0.6559 | Time: 0.0301
# Epoch 00057 | Train Acc: 0.7848 | Train Loss: 0.6289 | Valid Acc: 0.7848 | Valid loss: 0.6289 | Time: 0.0301
# Epoch 00058 | Train Acc: 0.7943 | Train Loss: 0.6069 | Valid Acc: 0.7943 | Valid loss: 0.6069 | Time: 0.0300
# Epoch 00059 | Train Acc: 0.8058 | Train Loss: 0.5781 | Valid Acc: 0.8058 | Valid loss: 0.5781 | Time: 0.0300
# Epoch 00060 | Train Acc: 0.8114 | Train Loss: 0.5592 | Valid Acc: 0.8114 | Valid loss: 0.5592 | Time: 0.0300
# Epoch 00061 | Train Acc: 0.8202 | Train Loss: 0.5342 | Valid Acc: 0.8202 | Valid loss: 0.5342 | Time: 0.0300
# Epoch 00062 | Train Acc: 0.8269 | Train Loss: 0.5156 | Valid Acc: 0.8269 | Valid loss: 0.5156 | Time: 0.0299
# Epoch 00063 | Train Acc: 0.8333 | Train Loss: 0.4958 | Valid Acc: 0.8333 | Valid loss: 0.4958 | Time: 0.0299
# Epoch 00064 | Train Acc: 0.8407 | Train Loss: 0.4758 | Valid Acc: 0.8407 | Valid loss: 0.4758 | Time: 0.0299
# Epoch 00065 | Train Acc: 0.8454 | Train Loss: 0.4602 | Valid Acc: 0.8454 | Valid loss: 0.4602 | Time: 0.0299
# Epoch 00066 | Train Acc: 0.8519 | Train Loss: 0.4409 | Valid Acc: 0.8519 | Valid loss: 0.4409 | Time: 0.0299
# Epoch 00067 | Train Acc: 0.8555 | Train Loss: 0.4276 | Valid Acc: 0.8555 | Valid loss: 0.4276 | Time: 0.0299
# Epoch 00068 | Train Acc: 0.8598 | Train Loss: 0.4113 | Valid Acc: 0.8598 | Valid loss: 0.4113 | Time: 0.0299
# Epoch 00069 | Train Acc: 0.8646 | Train Loss: 0.3986 | Valid Acc: 0.8646 | Valid loss: 0.3986 | Time: 0.0299
# Epoch 00070 | Train Acc: 0.8687 | Train Loss: 0.3854 | Valid Acc: 0.8687 | Valid loss: 0.3854 | Time: 0.0299
# Epoch 00071 | Train Acc: 0.8715 | Train Loss: 0.3729 | Valid Acc: 0.8715 | Valid loss: 0.3729 | Time: 0.0299
# Epoch 00072 | Train Acc: 0.8762 | Train Loss: 0.3620 | Valid Acc: 0.8762 | Valid loss: 0.3620 | Time: 0.0299
# Epoch 00073 | Train Acc: 0.8793 | Train Loss: 0.3500 | Valid Acc: 0.8793 | Valid loss: 0.3500 | Time: 0.0299
# Epoch 00074 | Train Acc: 0.8829 | Train Loss: 0.3406 | Valid Acc: 0.8829 | Valid loss: 0.3406 | Time: 0.0299
# Epoch 00075 | Train Acc: 0.8872 | Train Loss: 0.3296 | Valid Acc: 0.8872 | Valid loss: 0.3296 | Time: 0.0299
# Epoch 00076 | Train Acc: 0.8912 | Train Loss: 0.3212 | Valid Acc: 0.8912 | Valid loss: 0.3212 | Time: 0.0299
# Epoch 00077 | Train Acc: 0.8948 | Train Loss: 0.3114 | Valid Acc: 0.8948 | Valid loss: 0.3114 | Time: 0.0299
# Epoch 00078 | Train Acc: 0.8965 | Train Loss: 0.3038 | Valid Acc: 0.8965 | Valid loss: 0.3038 | Time: 0.0299
# Epoch 00079 | Train Acc: 0.8989 | Train Loss: 0.2953 | Valid Acc: 0.8989 | Valid loss: 0.2953 | Time: 0.0299
# Epoch 00080 | Train Acc: 0.9008 | Train Loss: 0.2881 | Valid Acc: 0.9008 | Valid loss: 0.2881 | Time: 0.0299
# Epoch 00081 | Train Acc: 0.9026 | Train Loss: 0.2806 | Valid Acc: 0.9026 | Valid loss: 0.2806 | Time: 0.0299
# Epoch 00082 | Train Acc: 0.9043 | Train Loss: 0.2740 | Valid Acc: 0.9043 | Valid loss: 0.2740 | Time: 0.0299
# Epoch 00083 | Train Acc: 0.9060 | Train Loss: 0.2675 | Valid Acc: 0.9060 | Valid loss: 0.2675 | Time: 0.0299
# Epoch 00084 | Train Acc: 0.9074 | Train Loss: 0.2615 | Valid Acc: 0.9074 | Valid loss: 0.2615 | Time: 0.0299
# Epoch 00085 | Train Acc: 0.9096 | Train Loss: 0.2557 | Valid Acc: 0.9096 | Valid loss: 0.2557 | Time: 0.0299
# Epoch 00086 | Train Acc: 0.9112 | Train Loss: 0.2500 | Valid Acc: 0.9112 | Valid loss: 0.2500 | Time: 0.0299
# Epoch 00087 | Train Acc: 0.9135 | Train Loss: 0.2449 | Valid Acc: 0.9135 | Valid loss: 0.2449 | Time: 0.0299
# Epoch 00088 | Train Acc: 0.9152 | Train Loss: 0.2397 | Valid Acc: 0.9152 | Valid loss: 0.2397 | Time: 0.0299
# Epoch 00089 | Train Acc: 0.9168 | Train Loss: 0.2352 | Valid Acc: 0.9168 | Valid loss: 0.2352 | Time: 0.0299
# Epoch 00090 | Train Acc: 0.9174 | Train Loss: 0.2305 | Valid Acc: 0.9174 | Valid loss: 0.2305 | Time: 0.0299
# Epoch 00091 | Train Acc: 0.9190 | Train Loss: 0.2263 | Valid Acc: 0.9190 | Valid loss: 0.2263 | Time: 0.0299
# Epoch 00092 | Train Acc: 0.9210 | Train Loss: 0.2220 | Valid Acc: 0.9210 | Valid loss: 0.2220 | Time: 0.0299
# Epoch 00093 | Train Acc: 0.9225 | Train Loss: 0.2182 | Valid Acc: 0.9225 | Valid loss: 0.2182 | Time: 0.0299
# Epoch 00094 | Train Acc: 0.9237 | Train Loss: 0.2142 | Valid Acc: 0.9237 | Valid loss: 0.2142 | Time: 0.0299
# Epoch 00095 | Train Acc: 0.9242 | Train Loss: 0.2107 | Valid Acc: 0.9242 | Valid loss: 0.2107 | Time: 0.0298
# Epoch 00096 | Train Acc: 0.9256 | Train Loss: 0.2071 | Valid Acc: 0.9256 | Valid loss: 0.2071 | Time: 0.0298
# Epoch 00097 | Train Acc: 0.9265 | Train Loss: 0.2038 | Valid Acc: 0.9265 | Valid loss: 0.2038 | Time: 0.0298
# Epoch 00098 | Train Acc: 0.9282 | Train Loss: 0.2005 | Valid Acc: 0.9282 | Valid loss: 0.2005 | Time: 0.0298
# Epoch 00099 | Train Acc: 0.9288 | Train Loss: 0.1974 | Valid Acc: 0.9288 | Valid loss: 0.1974 | Time: 0.0298
#
# Test Acc: 0.6750 | Test loss: 5.6905
